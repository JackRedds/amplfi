# %%
import os
import importlib
import sys
import torch
import matplotlib.pyplot as plt
import pandas as pd

device = torch.device('cuda') if torch.cuda.is_available() else 'cpu'
os.environ['AMPLFI_OUTDIR'] = '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg'
os.environ['AMPLFI_DATADIR'] = '/home/aframe/dev/o4_llpic/amplfi/hl/data'

# %%
module_path = "/home/jack.redepenning/amplfi_dir/amplfi/amplfi/__init__.py"
module_name = "amplfi"

# %%
spec = importlib.util.spec_from_file_location(module_name, module_path)
amplfi = importlib.util.module_from_spec(spec)
sys.modules[module_name] = amplfi
spec.loader.exec_module(amplfi)
print(amplfi.__file__)  # Should now point to your local repo
# Out:
# /home/jack.redepenning/amplfi_dir/amplfi/amplfi/__init__.py

# %%
ckpt_path = "/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt"
config_path = "/home/jack.redepenning/amplfi_dir/amplfi/runs/sg_sky_loc/sg.yaml"
param_path = "/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg/parameters.hdf5"

# %%
from amplfi.train.data.datasets.base import AmplfiDataset
from amplfi.train.models.base import AmplfiModel
from amplfi.train.cli.flow import AmplfiFlowCLI

cli = AmplfiFlowCLI(
        AmplfiModel,
        AmplfiDataset,
        subclass_mode_model=True,
        subclass_mode_data=True,
        save_config_kwargs={"overwrite": True},
        seed_everything_default=101588,
        args=[
        "test",             # Subcommand
        "--config", config_path,
        "--ckpt_path", ckpt_path,
        ]
)
# Out:
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/lightning/pytorch/cli.py:528: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['--f=/run/user/48090/jupyter/runtime/kernel-v3c897faa53db365eaa138aafbc04a9f3176f98c83.json'], args=['test', '--config', '/home/jack.redepenning/amplfi_dir/amplfi/runs/sg_sky_loc/sg.yaml', '--ckpt_path', '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt'].
# Seed set to 101588
# Seed set to 101588
# 2025-10-22 14:08:17,520 - root - INFO - Downloading data to /home/aframe/dev/o4_llpic/amplfi/hl/data
# Trainer will use only 1 of 4 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=4)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: redep028 (redep028-university-of-minnesota). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg/train_logs/wandb/run-20251022_140818-z2mr5zl0</code>
# Syncing run <strong><a href='https://wandb.ai/redep028-university-of-minnesota/amplfi/runs/z2mr5zl0' target="_blank">exalted-sound-276</a></strong> to <a href='https://wandb.ai/redep028-university-of-minnesota/amplfi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/redep028-university-of-minnesota/amplfi' target="_blank">https://wandb.ai/redep028-university-of-minnesota/amplfi</a>
#  View run at <a href='https://wandb.ai/redep028-university-of-minnesota/amplfi/runs/z2mr5zl0' target="_blank">https://wandb.ai/redep028-university-of-minnesota/amplfi/runs/z2mr5zl0</a>
# 2025-10-22 14:08:19,375 - FlowDataset - INFO - Setting up data for stage TrainerFn.TESTING
# 2025-10-22 14:08:19,377 - FlowDataset - INFO - Using 83 files with a total duration of 9.444 days for testing
# 2025-10-22 14:08:19,383 - FlowDataset - INFO - Inferred sample rate of 2048.0 Hz
# 2025-10-22 14:08:19,388 - FlowDataset - INFO - Loaded 1 waveforms for testing
# 2025-10-22 14:08:19,389 - FlowDataset - INFO - Building torch Modules and transferring to device
# 2025-10-22 14:08:19,391 - FlowDataset - INFO - Using pre-fit standard scaler
# Restoring states from the checkpoint path at /home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:362: The dirpath has changed from '/projects/bcse/jredepenning//amplfi-outdir/run5/sg_sky_loc/train_logs/amplfi/re0zo7ef/checkpoints' to '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg/train_logs/amplfi/z2mr5zl0/checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Loaded model weights from the checkpoint at /home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# 2025-10-22 14:08:50,656 - FlowModel - INFO - Removed 20/10000 total samples outside of prior range
# 2025-10-22 14:08:56,496 - FlowModel - INFO - Making PP plot
# 14:08 bilby INFO    : Key: KS-test p-value
# 14:08 bilby INFO    : phase: 0.7294589178356712
# 14:08 bilby INFO    : dec: 0.9144288577154309
# 14:08 bilby INFO    : psi: 0.6741482965931864
# 14:08 bilby INFO    : phi: 0.9068136272545089
# 14:08 bilby INFO    : Combined p-value: 0.9866874185229559
# Crossmatching skymaps:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/ligo/skymap/postprocess/crossmatch.py:395: RuntimeWarning: invalid value encountered in subtract
#   contour_dists = (hi - lo).tolist()
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/ligo/skymap/postprocess/crossmatch.py:414: RuntimeWarning: invalid value encountered in divide
#   dP_dV = dP / dV
# TEST Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                           	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                            	|  -              	|  131            	|  210.55         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Callback]CrossMatchStatistics.on_test_epoch_end                                                                                                                 	|  169.76         	|  1              	|  169.76         	|  80.627         	|
# |  [LightningDataModule]FlowDataset.test_dataloader                                                                                                                 	|  10.75          	|  1              	|  10.75          	|  5.1056         	|
# |  [Callback]SaveInjectionParameters.on_test_epoch_start                                                                                                            	|  10.173         	|  1              	|  10.173         	|  4.8313         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                   	|  3.8043         	|  1              	|  3.8043         	|  1.8068         	|
# |  [LightningDataModule]FlowDataset.on_after_batch_transfer                                                                                                         	|  3.8029         	|  1              	|  3.8029         	|  1.8062         	|
# |  [Callback]PlotMollview.on_test_batch_end                                                                                                                         	|  2.8142         	|  1              	|  2.8142         	|  1.3366         	|
# |  [Callback]PlotCorner.on_test_batch_end                                                                                                                           	|  2.5627         	|  1              	|  2.5627         	|  1.2171         	|
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                         	|  1.9628         	|  1              	|  1.9628         	|  0.93223        	|
# |  [Callback]SaveConfigCallback.setup                                                                                                                               	|  1.7935         	|  1              	|  1.7935         	|  0.85179        	|
# |  [Callback]ProbProbPlot.on_test_epoch_end                                                                                                                         	|  1.5449         	|  1              	|  1.5449         	|  0.73375        	|
# |  [Callback]SaveFITS.on_test_batch_end                                                                                                                             	|  0.44631        	|  1              	|  0.44631        	|  0.21197        	|
# |  [LightningDataModule]FlowDataset.setup                                                                                                                           	|  0.30164        	|  1              	|  0.30164        	|  0.14326        	|
# |  [Callback]SaveInjectionParameters.on_test_epoch_end                                                                                                              	|  0.15278        	|  1              	|  0.15278        	|  0.072563       	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                          	|  0.018161       	|  1              	|  0.018161       	|  0.0086254      	|
# |  [_EvaluationLoop].test_next                                                                                                                                      	|  0.0087774      	|  1              	|  0.0087774      	|  0.0041687      	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                                    	|  0.0027552      	|  1              	|  0.0027552      	|  0.0013085      	|
# |  [LightningModule]FlowModel.on_test_model_eval                                                                                                                    	|  0.0017445      	|  1              	|  0.0017445      	|  0.00082855     	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                            	|  0.001438       	|  1              	|  0.001438       	|  0.00068295     	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                                      	|  0.0011143      	|  1              	|  0.0011143      	|  0.00052921     	|
# |  [LightningModule]FlowModel.transfer_batch_to_device                                                                                                              	|  0.0010182      	|  1              	|  0.0010182      	|  0.00048359     	|
# |  [LightningModule]FlowModel.configure_callbacks                                                                                                                   	|  0.00082785     	|  1              	|  0.00082785     	|  0.00039318     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup              	|  0.00019362     	|  1              	|  0.00019362     	|  9.1959e-05     	|
# |  [Callback]SaveFITS.on_test_epoch_start                                                                                                                           	|  0.00012265     	|  1              	|  0.00012265     	|  5.825e-05      	|
# |  [Callback]SaveFITS.on_test_epoch_end                                                                                                                             	|  6.2067e-05     	|  1              	|  6.2067e-05     	|  2.9478e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end  	|  5.4583e-05     	|  1              	|  5.4583e-05     	|  2.5924e-05     	|
# |  [LightningDataModule]FlowDataset.prepare_data                                                                                                                    	|  2.6888e-05     	|  1              	|  2.6888e-05     	|  1.277e-05      	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                             	|  2.5456e-05     	|  1              	|  2.5456e-05     	|  1.209e-05      	|
# |  [LightningModule]FlowModel.on_test_batch_end                                                                                                                     	|  2.327e-05      	|  1              	|  2.327e-05      	|  1.1052e-05     	|
# |  [Callback]PlotMollview.on_test_end                                                                                                                               	|  2.1778e-05     	|  1              	|  2.1778e-05     	|  1.0343e-05     	|
# |  [Callback]CrossMatchStatistics.on_test_batch_end                                                                                                                 	|  1.9814e-05     	|  1              	|  1.9814e-05     	|  9.4104e-06     	|
# |  [Callback]SaveInjectionParameters.on_test_batch_end                                                                                                              	|  1.8909e-05     	|  1              	|  1.8909e-05     	|  8.9806e-06     	|
# |  [LightningModule]FlowModel.on_test_epoch_start                                                                                                                   	|  1.5398e-05     	|  1              	|  1.5398e-05     	|  7.3131e-06     	|
# |  [LightningModule]FlowModel.on_test_batch_start                                                                                                                   	|  1.0625e-05     	|  1              	|  1.0625e-05     	|  5.0462e-06     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                  	|  1.0046e-05     	|  1              	|  1.0046e-05     	|  4.7712e-06     	|
# |  [Callback]LearningRateMonitor.on_test_epoch_start                                                                                                                	|  7.719e-06      	|  1              	|  7.719e-06      	|  3.6661e-06     	|
# |  [Callback]LearningRateMonitor.setup                                                                                                                              	|  7.455e-06      	|  1              	|  7.455e-06      	|  3.5407e-06     	|
# |  [Callback]LearningRateMonitor.on_test_end                                                                                                                        	|  7.2329e-06     	|  1              	|  7.2329e-06     	|  3.4352e-06     	|
# |  [Callback]LearningRateMonitor.on_test_start                                                                                                                      	|  5.8908e-06     	|  1              	|  5.8908e-06     	|  2.7978e-06     	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                                       	|  5.2871e-06     	|  1              	|  5.2871e-06     	|  2.5111e-06     	|
# |  [LightningModule]FlowModel.on_test_epoch_end                                                                                                                     	|  5.2741e-06     	|  1              	|  5.2741e-06     	|  2.5049e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                     	|  5.058e-06      	|  1              	|  5.058e-06      	|  2.4022e-06     	|
# |  [LightningDataModule]FlowDataset.teardown                                                                                                                        	|  4.834e-06      	|  1              	|  4.834e-06      	|  2.2959e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                       	|  4.4371e-06     	|  1              	|  4.4371e-06     	|  2.1073e-06     	|
# |  [LightningModule]FlowModel.setup                                                                                                                                 	|  4.393e-06      	|  1              	|  4.393e-06      	|  2.0864e-06     	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                               	|  3.939e-06      	|  1              	|  3.939e-06      	|  1.8708e-06     	|
# |  [Callback]LearningRateMonitor.on_load_checkpoint                                                                                                                 	|  3.9171e-06     	|  1              	|  3.9171e-06     	|  1.8604e-06     	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                         	|  3.401e-06      	|  1              	|  3.401e-06      	|  1.6152e-06     	|
# |  [Callback]LearningRateMonitor.on_test_batch_end                                                                                                                  	|  3.3751e-06     	|  1              	|  3.3751e-06     	|  1.603e-06      	|
# |  [Callback]LearningRateMonitor.teardown                                                                                                                           	|  3.36e-06       	|  1              	|  3.36e-06       	|  1.5958e-06     	|
# |  [Callback]LearningRateMonitor.on_test_batch_start                                                                                                                	|  3.332e-06      	|  1              	|  3.332e-06      	|  1.5825e-06     	|
# |  [Callback]SaveFITS.on_test_start                                                                                                                                 	|  3.3109e-06     	|  1              	|  3.3109e-06     	|  1.5725e-06     	|
# |  [Callback]SaveWandbUrl.on_test_start                                                                                                                             	|  3.1819e-06     	|  1              	|  3.1819e-06     	|  1.5112e-06     	|
# |  [Callback]LearningRateMonitor.on_test_epoch_end                                                                                                                  	|  3.0969e-06     	|  1              	|  3.0969e-06     	|  1.4708e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start      	|  2.9481e-06     	|  1              	|  2.9481e-06     	|  1.4002e-06     	|
# |  [LightningModule]FlowModel.on_load_checkpoint                                                                                                                    	|  2.804e-06      	|  1              	|  2.804e-06      	|  1.3317e-06     	|
# |  [Callback]SaveWandbUrl.setup                                                                                                                                     	|  2.7709e-06     	|  1              	|  2.7709e-06     	|  1.316e-06      	|
# |  [Callback]SaveInjectionParameters.on_test_start                                                                                                                  	|  2.7269e-06     	|  1              	|  2.7269e-06     	|  1.2951e-06     	|
# |  [Callback]ProbProbPlot.on_test_start                                                                                                                             	|  2.6361e-06     	|  1              	|  2.6361e-06     	|  1.252e-06      	|
# |  [LightningModule]FlowModel.on_before_batch_transfer                                                                                                              	|  2.506e-06      	|  1              	|  2.506e-06      	|  1.1902e-06     	|
# |  [Callback]SaveFITS.on_load_checkpoint                                                                                                                            	|  2.465e-06      	|  1              	|  2.465e-06      	|  1.1707e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end  	|  2.4301e-06     	|  1              	|  2.4301e-06     	|  1.1541e-06     	|
# |  [Callback]SaveConfigCallback.on_test_end                                                                                                                         	|  2.336e-06      	|  1              	|  2.336e-06      	|  1.1095e-06     	|
# |  [Callback]SaveConfigCallback.on_load_checkpoint                                                                                                                  	|  2.2692e-06     	|  1              	|  2.2692e-06     	|  1.0777e-06     	|
# |  [Callback]PlotMollview.on_test_start                                                                                                                             	|  2.258e-06      	|  1              	|  2.258e-06      	|  1.0724e-06     	|
# |  [LightningModule]FlowModel.on_test_start                                                                                                                         	|  2.258e-06      	|  1              	|  2.258e-06      	|  1.0724e-06     	|
# |  [Callback]PlotCorner.on_test_start                                                                                                                               	|  2.21e-06       	|  1              	|  2.21e-06       	|  1.0496e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                                     	|  2.102e-06      	|  1              	|  2.102e-06      	|  9.9832e-07     	|
# |  [Callback]SaveWandbUrl.on_test_batch_start                                                                                                                       	|  2.092e-06      	|  1              	|  2.092e-06      	|  9.9356e-07     	|
# |  [Callback]SaveWandbUrl.on_test_end                                                                                                                               	|  2.0498e-06     	|  1              	|  2.0498e-06     	|  9.7355e-07     	|
# |  [Callback]CrossMatchStatistics.on_test_start                                                                                                                     	|  1.9539e-06     	|  1              	|  1.9539e-06     	|  9.2799e-07     	|
# |  [Callback]SaveFITS.on_test_end                                                                                                                                   	|  1.9511e-06     	|  1              	|  1.9511e-06     	|  9.2666e-07     	|
# |  [Callback]PlotMollview.on_test_epoch_start                                                                                                                       	|  1.892e-06      	|  1              	|  1.892e-06      	|  8.9858e-07     	|
# |  [LightningModule]FlowModel.on_test_end                                                                                                                           	|  1.892e-06      	|  1              	|  1.892e-06      	|  8.9858e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start	|  1.8869e-06     	|  1              	|  1.8869e-06     	|  8.9614e-07     	|
# |  [Callback]SaveConfigCallback.teardown                                                                                                                            	|  1.8519e-06     	|  1              	|  1.8519e-06     	|  8.7956e-07     	|
# |  [Callback]ModelSummary.on_load_checkpoint                                                                                                                        	|  1.794e-06      	|  1              	|  1.794e-06      	|  8.5202e-07     	|
# |  [Callback]SaveFITS.setup                                                                                                                                         	|  1.79e-06       	|  1              	|  1.79e-06       	|  8.5014e-07     	|
# |  [Callback]ProbProbPlot.on_test_end                                                                                                                               	|  1.7812e-06     	|  1              	|  1.7812e-06     	|  8.4594e-07     	|
# |  [Callback]PlotCorner.on_test_epoch_end                                                                                                                           	|  1.7809e-06     	|  1              	|  1.7809e-06     	|  8.4583e-07     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                               	|  1.766e-06      	|  1              	|  1.766e-06      	|  8.3875e-07     	|
# |  [Callback]TQDMProgressBar.on_load_checkpoint                                                                                                                     	|  1.749e-06      	|  1              	|  1.749e-06      	|  8.3068e-07     	|
# |  [Callback]SaveInjectionParameters.on_test_end                                                                                                                    	|  1.7481e-06     	|  1              	|  1.7481e-06     	|  8.3024e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end        	|  1.6098e-06     	|  1              	|  1.6098e-06     	|  7.6455e-07     	|
# |  [Callback]ProbProbPlot.on_test_epoch_start                                                                                                                       	|  1.594e-06      	|  1              	|  1.594e-06      	|  7.5703e-07     	|
# |  [Callback]SaveConfigCallback.on_test_epoch_start                                                                                                                 	|  1.59e-06       	|  1              	|  1.59e-06       	|  7.5515e-07     	|
# |  [Callback]PlotMollview.on_load_checkpoint                                                                                                                        	|  1.58e-06       	|  1              	|  1.58e-06       	|  7.504e-07      	|
# |  [Callback]ProbProbPlot.on_load_checkpoint                                                                                                                        	|  1.5791e-06     	|  1              	|  1.5791e-06     	|  7.4996e-07     	|
# |  [Callback]SaveFITS.on_test_batch_start                                                                                                                           	|  1.573e-06      	|  1              	|  1.573e-06      	|  7.4708e-07     	|
# |  [Callback]SaveFITS.teardown                                                                                                                                      	|  1.5721e-06     	|  1              	|  1.5721e-06     	|  7.4664e-07     	|
# |  [Callback]CrossMatchStatistics.on_test_end                                                                                                                       	|  1.5262e-06     	|  1              	|  1.5262e-06     	|  7.2485e-07     	|
# |  [Callback]PlotCorner.on_test_end                                                                                                                                 	|  1.5199e-06     	|  1              	|  1.5199e-06     	|  7.2187e-07     	|
# |  [Callback]SaveConfigCallback.on_test_batch_start                                                                                                                 	|  1.519e-06      	|  1              	|  1.519e-06      	|  7.2143e-07     	|
# |  [Callback]PlotCorner.setup                                                                                                                                       	|  1.512e-06      	|  1              	|  1.512e-06      	|  7.1811e-07     	|
# |  [Callback]PlotMollview.on_test_epoch_end                                                                                                                         	|  1.4941e-06     	|  1              	|  1.4941e-06     	|  7.0959e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_load_checkpoint 	|  1.488e-06      	|  1              	|  1.488e-06      	|  7.0672e-07     	|
# |  [Callback]PlotMollview.setup                                                                                                                                     	|  1.455e-06      	|  1              	|  1.455e-06      	|  6.9102e-07     	|
# |  [Callback]SaveWandbUrl.on_test_epoch_start                                                                                                                       	|  1.4359e-06     	|  1              	|  1.4359e-06     	|  6.8195e-07     	|
# |  [Callback]SaveConfigCallback.on_test_start                                                                                                                       	|  1.4319e-06     	|  1              	|  1.4319e-06     	|  6.8007e-07     	|
# |  [Callback]CrossMatchStatistics.on_test_epoch_start                                                                                                               	|  1.4249e-06     	|  1              	|  1.4249e-06     	|  6.7675e-07     	|
# |  [Callback]ProbProbPlot.on_test_batch_start                                                                                                                       	|  1.4151e-06     	|  1              	|  1.4151e-06     	|  6.7211e-07     	|
# |  [Callback]ProbProbPlot.setup                                                                                                                                     	|  1.4061e-06     	|  1              	|  1.4061e-06     	|  6.6779e-07     	|
# |  [Callback]SaveConfigCallback.on_test_epoch_end                                                                                                                   	|  1.3548e-06     	|  1              	|  1.3548e-06     	|  6.4347e-07     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                       	|  1.3381e-06     	|  1              	|  1.3381e-06     	|  6.355e-07      	|
# |  [LightningModule]FlowModel.teardown                                                                                                                              	|  1.336e-06      	|  1              	|  1.336e-06      	|  6.3451e-07     	|
# |  [Callback]PlotCorner.on_load_checkpoint                                                                                                                          	|  1.333e-06      	|  1              	|  1.333e-06      	|  6.3307e-07     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                    	|  1.3241e-06     	|  1              	|  1.3241e-06     	|  6.2887e-07     	|
# |  [Callback]SaveWandbUrl.on_test_epoch_end                                                                                                                         	|  1.3181e-06     	|  1              	|  1.3181e-06     	|  6.2599e-07     	|
# |  [Callback]SaveInjectionParameters.setup                                                                                                                          	|  1.309e-06      	|  1              	|  1.309e-06      	|  6.2168e-07     	|
# |  [Callback]PlotMollview.on_test_batch_start                                                                                                                       	|  1.3071e-06     	|  1              	|  1.3071e-06     	|  6.208e-07      	|
# |  [Callback]SaveInjectionParameters.on_test_batch_start                                                                                                            	|  1.3039e-06     	|  1              	|  1.3039e-06     	|  6.1925e-07     	|
# |  [Callback]SaveWandbUrl.on_load_checkpoint                                                                                                                        	|  1.2729e-06     	|  1              	|  1.2729e-06     	|  6.0454e-07     	|
# |  [Callback]PlotCorner.on_test_epoch_start                                                                                                                         	|  1.2559e-06     	|  1              	|  1.2559e-06     	|  5.9647e-07     	|
# |  [Callback]CrossMatchStatistics.on_load_checkpoint                                                                                                                	|  1.2501e-06     	|  1              	|  1.2501e-06     	|  5.9371e-07     	|
# |  [Callback]PlotMollview.teardown                                                                                                                                  	|  1.2389e-06     	|  1              	|  1.2389e-06     	|  5.884e-07      	|
# |  [Callback]SaveConfigCallback.on_test_batch_end                                                                                                                   	|  1.237e-06      	|  1              	|  1.237e-06      	|  5.8751e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown           	|  1.2231e-06     	|  1              	|  1.2231e-06     	|  5.8088e-07     	|
# |  [Callback]ProbProbPlot.on_test_batch_end                                                                                                                         	|  1.2151e-06     	|  1              	|  1.2151e-06     	|  5.7712e-07     	|
# |  [Callback]CrossMatchStatistics.on_test_batch_start                                                                                                               	|  1.197e-06      	|  1              	|  1.197e-06      	|  5.6849e-07     	|
# |  [Callback]PlotCorner.teardown                                                                                                                                    	|  1.197e-06      	|  1              	|  1.197e-06      	|  5.6849e-07     	|
# |  [Callback]ProbProbPlot.teardown                                                                                                                                  	|  1.1919e-06     	|  1              	|  1.1919e-06     	|  5.6606e-07     	|
# |  [Callback]SaveWandbUrl.on_test_batch_end                                                                                                                         	|  1.19e-06       	|  1              	|  1.19e-06       	|  5.6518e-07     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start	|  1.1809e-06     	|  1              	|  1.1809e-06     	|  5.6086e-07     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                  	|  1.177e-06      	|  1              	|  1.177e-06      	|  5.5898e-07     	|
# |  [Callback]SaveInjectionParameters.on_load_checkpoint                                                                                                             	|  1.1711e-06     	|  1              	|  1.1711e-06     	|  5.5622e-07     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                                      	|  1.1679e-06     	|  1              	|  1.1679e-06     	|  5.5467e-07     	|
# |  [Callback]CrossMatchStatistics.setup                                                                                                                             	|  1.1672e-06     	|  1              	|  1.1672e-06     	|  5.5434e-07     	|
# |  [Callback]CrossMatchStatistics.teardown                                                                                                                          	|  1.163e-06      	|  1              	|  1.163e-06      	|  5.5235e-07     	|
# |  [Callback]SaveInjectionParameters.teardown                                                                                                                       	|  1.1439e-06     	|  1              	|  1.1439e-06     	|  5.4328e-07     	|
# |  [Callback]SaveWandbUrl.teardown                                                                                                                                  	|  1.0571e-06     	|  1              	|  1.0571e-06     	|  5.0203e-07     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                         	|  1.0198e-06     	|  1              	|  1.0198e-06     	|  4.8434e-07     	|
# |  [Callback]PlotCorner.on_test_batch_start                                                                                                                         	|  1.0049e-06     	|  1              	|  1.0049e-06     	|  4.7726e-07     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Set parameters to prepare for generating sine Gaussian waveforms

# %%
# Desired duration of time-domain waveform
waveform_duration = 7
# Sample rate of all the data we'll be using today
sample_rate = 2048

nyquist = sample_rate / 2
num_samples = int(waveform_duration * sample_rate)
num_freqs = num_samples // 2 + 1

# %% [markdown]
# ### Define priors for waveform

# %%
from ml4gw.distributions import LogUniform
from torch.distributions import Uniform
from ml4gw.waveforms import SineGaussian
import numpy as np

min_freq = 32
max_freq = 1024

min_qual = 25
max_qual = 75

min_hrss = 1e-21
max_hrss = 2e-21

min_phase = 0
max_phase = 2 * np.pi

min_ecc = 0
max_ecc = 0.01

min_dec = -np.pi / 2
max_dec = np.pi / 2

min_psi = 0
max_psi = np.pi

min_phi = 0
max_phi = 2 * np.pi

corner_range = [(min_phase, max_phase), (min_dec, max_dec), (min_psi, max_psi), (min_phi, max_phi)]
# On CPU, keep the number of waveforms around 100. On GPU, you can go higher
num_waveforms = 3
num_packet = 1

param_dict = {
    "frequency": Uniform(min_freq, max_freq, False),
    "quality": Uniform(min_qual, max_qual, False),
    "hrss": Uniform(min_hrss, max_hrss, False),
    "phase": Uniform(min_phase, max_phase, False),
    "eccentricity": Uniform(min_ecc, max_ecc, False),
}

# And then sample from each of those distributions
params = {
    k: v.sample((num_waveforms,)).cpu() for k, v in param_dict.items()
}

# %%
approximant = SineGaussian(sample_rate, waveform_duration)

cross, plus = approximant(**params)
cross = cross.mean(0).unsqueeze(0)
plus = plus.mean(0).unsqueeze(0)

params_packet = {
    k: torch.mean(v) for k, v in params.items()
}
times = torch.arange(0, waveform_duration, 1 / sample_rate)
# Calling the approximant with the frequency array, reference frequency, and waveform parameters
# returns the cross and plus polarizations
print(cross.shape, plus.shape)
# Out:
# torch.Size([1, 14336]) torch.Size([1, 14336])

# %%
# Set up data coming from both detectors
from ml4gw.gw import get_ifo_geometry, compute_observed_strain

# The interferometer geometry for V1 and K1 are also in ml4gw
ifos = ["H1", "L1"]
tensors, vertices = get_ifo_geometry(*ifos)

# %%
datamodule = cli.datamodule
model = cli.model
model.eval();

# %% [markdown]
# ### Load in background data

# %%
waveforms_dataloader, background_dataloader = datamodule.test_dataloader().datasets
background_data = next(iter(background_dataloader))
background_data = background_data[0][0].repeat(num_packet, 1, 1)
print(background_data.shape)
# Out:
# torch.Size([1, 2, 38912])

# %% [markdown]
# ### Inject sg waveforms into the background data and use amplfi to predict waveform parameters

# %%
# keep sky location and ecc const
strain, asds, parameters, snrs = datamodule.inject(background_data, cross, plus, params_packet)
batch = strain, asds, parameters
print(strain.shape)
print(asds.shape)
print(parameters.shape)
print(snrs.shape)
result = model.predict_step(batch, _)
# Out:
# torch.Size([1, 2, 10240])
# torch.Size([1, 2, 4995])
# torch.Size([1, 4])
# torch.Size([1])
# 2025-10-22 14:11:54,944 - FlowModel - INFO - Removed 52/10000 total samples outside of prior range

# %% [markdown]
# ### Corner Plot

# %%
import pandas as pd
params_df = pd.DataFrame(params)
params_df['dec'] = np.full(len(params_df), params_packet['dec'].item())
params_df['psi'] = np.full(len(params_df), params_packet['psi'].item())
params_df['phi'] = np.full(len(params_df), params_packet['phi'].item())
params_df = params_df[["phase", "dec", "psi", "phi"]]

# %%
import corner
param_vals = np.array([v.item() for k, v in params_packet.items()])
fig = result.plot_corner(save=False, levels=(0.5, 0.9), range = corner_range);
for vals in params_df.to_numpy():
    corner.overplot_lines(fig, vals, color='r')

# %% [markdown]
# ### Take the average of the 10000 samples generated from amplfi to generate a single waveform and see how this compares to waveform generated using actual values

# %%
posterior = result.posterior
post = {key: torch.tensor([posterior[key].mean()]) for key in posterior.keys()
        if key in param_dict.keys()}

# Phase of the two waveforms do not match up unless I set the phase for the posterior to be the
# same as the prior
# post['phase'] = params['phase']

# %%
post['frequency'] = params_packet['frequency']
post['quality'] = params_packet['quality']
post['hrss'] = params_packet['hrss']
post['eccentricity'] = params_packet['eccentricity']

# %%
post
# Out:
# {'phase': tensor([3.1909]),
#  'frequency': tensor(154.7564),
#  'quality': tensor(53.7245),
#  'hrss': tensor(1.3663e-21),
#  'eccentricity': tensor(0.0065)}

# %%
from scipy.stats import probplot
num_params = len(posterior.keys()[:-2])
fig, axes = plt.subplots(2, 2, sharex=True, figsize = (10, 10))
post_plot = posterior.to_numpy().T
key = posterior.keys()
probplot(post_plot[0], plot=axes[0, 0])
probplot(post_plot[1], plot=axes[0, 1])
probplot(post_plot[2], plot=axes[1, 0])
probplot(post_plot[3], plot=axes[1, 1])
axes[0, 0].set_title(key[0])
axes[0, 1].set_title(key[1])
axes[1, 0].set_title(key[2])
axes[1, 1].set_title(key[3])
plt.tight_layout()

# %% [markdown]
# ### Generate waveforms from prior values

# %%
waveforms = compute_observed_strain(
    dec=torch.tensor([params_packet['dec']]),
    psi=torch.tensor([params_packet['psi']]),
    phi=torch.tensor([params_packet['phi']]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross,
    plus=plus,
)

# %% [markdown]
# ### Generate waveforms from average of posterior values

# %%
cross_pred, plus_pred = approximant(**post)

waveforms_pred = compute_observed_strain(
    dec=torch.tensor([posterior['dec'].mean()]),
    psi=torch.tensor([posterior['psi'].mean()]),
    phi=torch.tensor([posterior['phi'].mean()]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross_pred,
    plus=plus_pred,
)
print(waveforms_pred.shape)
# Out:
# torch.Size([1, 2, 14336])

# %%
mean_waveform_pred = waveforms_pred.mean(0)
print(mean_waveform_pred.shape)
print(waveforms.shape)
# Out:
# torch.Size([2, 14336])
# torch.Size([1, 2, 14336])

# %% [markdown]
# ### Plot waveforms together

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=True, figsize=(15, 7))
ax[0].plot(times, waveforms[0, 0].cpu(), color='k', label="original", alpha=0.5)
ax[0].plot(times, mean_waveform_pred[0].cpu (), color='r', label="predicted", alpha=0.5)
ax[1].plot(times, waveforms[0, 1].cpu(), color='k', alpha=0.5)
ax[1].plot(times, mean_waveform_pred[1].cpu(), color='r', alpha=0.5)
ax[1].set_xlabel("Time (s)")
ax[0].set_ylabel("Strain H1")
ax[1].set_ylabel("Strain L1")
ax[0].legend()
ax[1].set_xlim(3, 4)
plt.show()

# %% [markdown]
# ### Try generating all 10000 waveforms first, then taking the average of all of the waveforms

# %%
posterior = result.posterior
post = {key: torch.tensor([posterior[key]]) for key in posterior.keys()
        if key in param_dict.keys()}

# %%
post['frequency'] = torch.full([len(post['phase'])], params_packet['frequency'].item())
post['quality'] = torch.full([len(post['phase'])], params_packet['quality'].item())
post['hrss'] = torch.full([len(post['phase'])], params_packet['hrss'].item())
post['eccentricity'] = torch.full([len(post['phase'])], params_packet['eccentricity'].item())

# %%
post
# Out:
# {'phase': tensor([[5.4503, 0.6852, 1.9444,  ..., 5.2330, 4.9070, 6.0787]]),
#  'frequency': tensor([154.7564]),
#  'quality': tensor([53.7245]),
#  'hrss': tensor([1.3663e-21]),
#  'eccentricity': tensor([0.0065])}

# %%
cross_pred, plus_pred = approximant(**post)

waveforms_pred = compute_observed_strain(
    dec=torch.tensor([posterior['dec']]),
    psi=torch.tensor([posterior['psi']]),
    phi=torch.tensor([posterior['phi']]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross_pred,
    plus=plus_pred,
)
print(waveforms_pred.shape)
# Out:
# torch.Size([9948, 2, 14336])

# %%
percentile_waveform_pred = np.percentile(waveforms_pred.cpu(), [5, 95], axis=0)
print(percentile_waveform_pred.shape)
print(mean_waveform_pred.shape)
print(waveforms.shape)
# Out:
# (2, 2, 14336)
# torch.Size([2, 14336])
# torch.Size([1, 2, 14336])

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=True, figsize=(10, 5))
ax[0].plot(times, waveforms[0, 0].cpu(), color='k', alpha=0.5)
ax[0].fill_between(times, percentile_waveform_pred[0, 0], percentile_waveform_pred[1, 0], alpha=0.5)
ax[1].plot(times, waveforms[0, 1].cpu(), color='k', alpha=0.5)
ax[1].fill_between(times, percentile_waveform_pred[0, 1], percentile_waveform_pred[1, 1], alpha=0.5)
ax[1].set_xlabel("Time (s)")
ax[0].set_ylabel("Strain H1")
ax[1].set_ylabel("Strain L1")
ax[1].set_xlim(3, 4)
plt.tight_layout()
# plt.savefig("./images/sg_packet.png")
plt.show()

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=(15, 7))
wave_ave = 0
num_waves = 1000
ip = len(waveforms_pred) // num_waves + 1
for wave in waveforms_pred[::ip, 0, :]:
    ax[0].plot(times, wave)
    wave_ave += wave
wave_ave /= num_waves
ax[1].plot(times, wave_ave)
ax[2].plot(times, waveforms[0, 0])
ax[0].set_xlim(3.4, 3.6)
plt.show()

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=(15, 7))
wave_ave = 0
ip = len(waveforms_pred) // num_waves + 1
for wave in waveforms_pred[::ip, 1, :]:
    ax[0].plot(times, wave)
    wave_ave += wave
wave_ave /= num_waves
ax[1].plot(times, wave_ave)
ax[2].plot(times, waveforms[0, 1])
# ax[0].set_xlim(3.4, 3.6)
plt.show()
