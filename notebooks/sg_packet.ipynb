# %%
import os
import importlib
import sys
import torch
import matplotlib.pyplot as plt
import pandas as pd

device = torch.device('cuda') if torch.cuda.is_available() else 'cpu'
os.environ['AMPLFI_OUTDIR'] = '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg'
os.environ['AMPLFI_DATADIR'] = '/home/aframe/dev/o4_llpic/amplfi/hl/data'

# %%
module_path = "/home/jack.redepenning/amplfi_dir/amplfi/amplfi/__init__.py"
module_name = "amplfi"

# %%
spec = importlib.util.spec_from_file_location(module_name, module_path)
amplfi = importlib.util.module_from_spec(spec)
sys.modules[module_name] = amplfi
spec.loader.exec_module(amplfi)
print(amplfi.__file__)  # Should now point to your local repo
# Out:
# /home/jack.redepenning/amplfi_dir/amplfi/amplfi/__init__.py

# %%
ckpt_path = "/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt"
config_path = "/home/jack.redepenning/amplfi_dir/amplfi/runs/sg_sky_loc/sg.yaml"
param_path = "/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg/parameters.hdf5"

# %%
from amplfi.train.data.datasets.base import AmplfiDataset
from amplfi.train.models.base import AmplfiModel
from amplfi.train.cli.flow import AmplfiFlowCLI

cli = AmplfiFlowCLI(
        AmplfiModel,
        AmplfiDataset,
        subclass_mode_model=True,
        subclass_mode_data=True,
        save_config_kwargs={"overwrite": True},
        seed_everything_default=101588,
        args=[
        "test",             # Subcommand
        "--config", config_path,
        "--ckpt_path", ckpt_path,
        ]
)
# Out:
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/lightning/pytorch/cli.py:528: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['--f=/run/user/48090/jupyter/runtime/kernel-v36a88a3cf090c62ed81b2c286b27898a1cb32d4e2.json'], args=['test', '--config', '/home/jack.redepenning/amplfi_dir/amplfi/runs/sg_sky_loc/sg.yaml', '--ckpt_path', '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt'].
# Seed set to 101588
# Seed set to 101588
# 2025-12-08 12:49:28,548 - root - INFO - Downloading data to /home/aframe/dev/o4_llpic/amplfi/hl/data
# Trainer will use only 1 of 4 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=4)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: redep028 (redep028-university-of-minnesota). Use `wandb login --relogin` to force relogin
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# 2025-12-08 12:49:30,487 - FlowDataset - INFO - Setting up data for stage TrainerFn.TESTING
# 2025-12-08 12:49:30,489 - FlowDataset - INFO - Using 83 files with a total duration of 9.444 days for testing
# 2025-12-08 12:49:30,494 - FlowDataset - INFO - Inferred sample rate of 2048.0 Hz
# 2025-12-08 12:49:30,497 - FlowDataset - INFO - Loaded 1 waveforms for testing
# 2025-12-08 12:49:30,499 - FlowDataset - INFO - Building torch Modules and transferring to device
# 2025-12-08 12:49:30,501 - FlowDataset - INFO - Using pre-fit standard scaler
# Restoring states from the checkpoint path at /home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:362: The dirpath has changed from '/projects/bcse/jredepenning//amplfi-outdir/sg_runs/sg_sky_loc/train_logs/amplfi/y9vno1fb/checkpoints' to '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg/train_logs/amplfi/im5m9rq0/checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Loaded model weights from the checkpoint at /home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# 2025-12-08 12:49:35,650 - FlowModel - INFO - Removed 30/10000 total samples outside of prior range
# 2025-12-08 12:49:37,452 - FlowModel - INFO - Making PP plot
# 12:49 bilby INFO    : Key: KS-test p-value
# 12:49 bilby INFO    : phase: 0.7366098294884655
# 12:49 bilby INFO    : dec: 0.8804413239719158
# 12:49 bilby INFO    : psi: 0.6746238716148445
# 12:49 bilby INFO    : phi: 0.29588766298896685
# 12:49 bilby INFO    : Combined p-value: 0.8490232092712622
# Crossmatching skymaps:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/ligo/skymap/postprocess/crossmatch.py:395: RuntimeWarning: invalid value encountered in subtract
#   contour_dists = (hi - lo).tolist()
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/ligo/skymap/postprocess/crossmatch.py:414: RuntimeWarning: invalid value encountered in divide
#   dP_dV = dP / dV
# TEST Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                           	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                            	|  -              	|  131            	|  12.389         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Callback]CrossMatchStatistics.on_test_epoch_end                                                                                                                 	|  2.4078         	|  1              	|  2.4078         	|  19.435         	|
# |  [Callback]SaveConfigCallback.setup                                                                                                                               	|  1.4331         	|  1              	|  1.4331         	|  11.568         	|
# |  [Callback]PlotCorner.on_test_batch_end                                                                                                                           	|  1.2026         	|  1              	|  1.2026         	|  9.7076         	|
# |  [Callback]ProbProbPlot.on_test_epoch_end                                                                                                                         	|  0.98527        	|  1              	|  0.98527        	|  7.953          	|
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                         	|  0.81016        	|  1              	|  0.81016        	|  6.5396         	|
# |  [Callback]PlotMollview.on_test_batch_end                                                                                                                         	|  0.53332        	|  1              	|  0.53332        	|  4.3049         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                   	|  0.42556        	|  1              	|  0.42556        	|  3.4351         	|
# |  [LightningDataModule]FlowDataset.on_after_batch_transfer                                                                                                         	|  0.42476        	|  1              	|  0.42476        	|  3.4286         	|
# |  [LightningDataModule]FlowDataset.test_dataloader                                                                                                                 	|  0.29436        	|  1              	|  0.29436        	|  2.376          	|
# |  [LightningDataModule]FlowDataset.setup                                                                                                                           	|  0.26465        	|  1              	|  0.26465        	|  2.1362         	|
# |  [Callback]SaveInjectionParameters.on_test_epoch_start                                                                                                            	|  0.2232         	|  1              	|  0.2232         	|  1.8017         	|
# |  [Callback]SaveFITS.on_test_batch_end                                                                                                                             	|  0.051368       	|  1              	|  0.051368       	|  0.41464        	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                          	|  0.018905       	|  1              	|  0.018905       	|  0.1526         	|
# |  [_EvaluationLoop].test_next                                                                                                                                      	|  0.0062519      	|  1              	|  0.0062519      	|  0.050464       	|
# |  [Callback]SaveInjectionParameters.on_test_epoch_end                                                                                                              	|  0.004381       	|  1              	|  0.004381       	|  0.035363       	|
# |  [LightningModule]FlowModel.on_test_model_eval                                                                                                                    	|  0.0017558      	|  1              	|  0.0017558      	|  0.014173       	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                                    	|  0.0012697      	|  1              	|  0.0012697      	|  0.010249       	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                            	|  0.00086521     	|  1              	|  0.00086521     	|  0.0069839      	|
# |  [LightningModule]FlowModel.configure_callbacks                                                                                                                   	|  0.00081428     	|  1              	|  0.00081428     	|  0.0065728      	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                                      	|  0.00075228     	|  1              	|  0.00075228     	|  0.0060724      	|
# |  [LightningModule]FlowModel.transfer_batch_to_device                                                                                                              	|  0.00066343     	|  1              	|  0.00066343     	|  0.0053552      	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup              	|  0.00011326     	|  1              	|  0.00011326     	|  0.00091424     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end  	|  2.9201e-05     	|  1              	|  2.9201e-05     	|  0.00023571     	|
# |  [Callback]CrossMatchStatistics.on_test_batch_end                                                                                                                 	|  2.2199e-05     	|  1              	|  2.2199e-05     	|  0.00017919     	|
# |  [LightningModule]FlowModel.on_test_batch_end                                                                                                                     	|  2.0089e-05     	|  1              	|  2.0089e-05     	|  0.00016216     	|
# |  [Callback]SaveFITS.teardown                                                                                                                                      	|  1.8128e-05     	|  1              	|  1.8128e-05     	|  0.00014633     	|
# |  [LightningDataModule]FlowDataset.prepare_data                                                                                                                    	|  1.7575e-05     	|  1              	|  1.7575e-05     	|  0.00014186     	|
# |  [Callback]SaveInjectionParameters.on_test_batch_end                                                                                                              	|  1.4e-05        	|  1              	|  1.4e-05        	|  0.00011301     	|
# |  [LightningModule]FlowModel.on_test_epoch_start                                                                                                                   	|  1.1296e-05     	|  1              	|  1.1296e-05     	|  9.118e-05      	|
# |  [Callback]LearningRateMonitor.on_test_start                                                                                                                      	|  8.989e-06      	|  1              	|  8.989e-06      	|  7.2559e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                  	|  7.436e-06      	|  1              	|  7.436e-06      	|  6.0023e-05     	|
# |  [Callback]SaveFITS.on_test_epoch_start                                                                                                                           	|  6.136e-06      	|  1              	|  6.136e-06      	|  4.9529e-05     	|
# |  [Callback]LearningRateMonitor.on_load_checkpoint                                                                                                                 	|  6.024e-06      	|  1              	|  6.024e-06      	|  4.8625e-05     	|
# |  [Callback]LearningRateMonitor.setup                                                                                                                              	|  5.8571e-06     	|  1              	|  5.8571e-06     	|  4.7278e-05     	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                             	|  5.3419e-06     	|  1              	|  5.3419e-06     	|  4.312e-05      	|
# |  [LightningDataModule]FlowDataset.teardown                                                                                                                        	|  4.641e-06      	|  1              	|  4.641e-06      	|  3.7462e-05     	|
# |  [LightningModule]FlowModel.on_test_start                                                                                                                         	|  4.235e-06      	|  1              	|  4.235e-06      	|  3.4184e-05     	|
# |  [Callback]LearningRateMonitor.on_test_end                                                                                                                        	|  3.8029e-06     	|  1              	|  3.8029e-06     	|  3.0697e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                     	|  3.76e-06       	|  1              	|  3.76e-06       	|  3.035e-05      	|
# |  [Callback]LearningRateMonitor.on_test_batch_start                                                                                                                	|  3.524e-06      	|  1              	|  3.524e-06      	|  2.8445e-05     	|
# |  [LightningModule]FlowModel.setup                                                                                                                                 	|  3.515e-06      	|  1              	|  3.515e-06      	|  2.8373e-05     	|
# |  [Callback]LearningRateMonitor.teardown                                                                                                                           	|  3.4841e-06     	|  1              	|  3.4841e-06     	|  2.8123e-05     	|
# |  [LightningModule]FlowModel.on_test_end                                                                                                                           	|  3.44e-06       	|  1              	|  3.44e-06       	|  2.7767e-05     	|
# |  [Callback]SaveFITS.on_load_checkpoint                                                                                                                            	|  3.438e-06      	|  1              	|  3.438e-06      	|  2.7751e-05     	|
# |  [LightningModule]FlowModel.on_test_epoch_end                                                                                                                     	|  3.414e-06      	|  1              	|  3.414e-06      	|  2.7557e-05     	|
# |  [Callback]SaveFITS.on_test_epoch_end                                                                                                                             	|  3.128e-06      	|  1              	|  3.128e-06      	|  2.5249e-05     	|
# |  [Callback]LearningRateMonitor.on_test_batch_end                                                                                                                  	|  2.995e-06      	|  1              	|  2.995e-06      	|  2.4176e-05     	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                         	|  2.9709e-06     	|  1              	|  2.9709e-06     	|  2.3981e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                       	|  2.788e-06      	|  1              	|  2.788e-06      	|  2.2505e-05     	|
# |  [Callback]LearningRateMonitor.on_test_epoch_end                                                                                                                  	|  2.7129e-06     	|  1              	|  2.7129e-06     	|  2.1899e-05     	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                                       	|  2.648e-06      	|  1              	|  2.648e-06      	|  2.1374e-05     	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                               	|  2.592e-06      	|  1              	|  2.592e-06      	|  2.0922e-05     	|
# |  [LightningModule]FlowModel.on_load_checkpoint                                                                                                                    	|  2.517e-06      	|  1              	|  2.517e-06      	|  2.0317e-05     	|
# |  [Callback]SaveConfigCallback.on_load_checkpoint                                                                                                                  	|  2.4399e-06     	|  1              	|  2.4399e-06     	|  1.9695e-05     	|
# |  [Callback]TQDMProgressBar.on_load_checkpoint                                                                                                                     	|  2.39e-06       	|  1              	|  2.39e-06       	|  1.9292e-05     	|
# |  [Callback]ModelSummary.setup                                                                                                                                     	|  2.249e-06      	|  1              	|  2.249e-06      	|  1.8154e-05     	|
# |  [Callback]SaveWandbUrl.setup                                                                                                                                     	|  2.238e-06      	|  1              	|  2.238e-06      	|  1.8065e-05     	|
# |  [Callback]PlotMollview.on_load_checkpoint                                                                                                                        	|  2.175e-06      	|  1              	|  2.175e-06      	|  1.7556e-05     	|
# |  [Callback]ModelSummary.on_load_checkpoint                                                                                                                        	|  2.1061e-06     	|  1              	|  2.1061e-06     	|  1.7e-05        	|
# |  [Callback]ProbProbPlot.on_load_checkpoint                                                                                                                        	|  1.9299e-06     	|  1              	|  1.9299e-06     	|  1.5578e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_load_checkpoint 	|  1.912e-06      	|  1              	|  1.912e-06      	|  1.5434e-05     	|
# |  [Callback]PlotCorner.on_load_checkpoint                                                                                                                          	|  1.91e-06       	|  1              	|  1.91e-06       	|  1.5418e-05     	|
# |  [LightningModule]FlowModel.on_before_batch_transfer                                                                                                              	|  1.883e-06      	|  1              	|  1.883e-06      	|  1.52e-05       	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end  	|  1.802e-06      	|  1              	|  1.802e-06      	|  1.4546e-05     	|
# |  [Callback]SaveWandbUrl.on_load_checkpoint                                                                                                                        	|  1.766e-06      	|  1              	|  1.766e-06      	|  1.4255e-05     	|
# |  [Callback]SaveWandbUrl.on_test_start                                                                                                                             	|  1.681e-06      	|  1              	|  1.681e-06      	|  1.3569e-05     	|
# |  [Callback]SaveInjectionParameters.on_load_checkpoint                                                                                                             	|  1.672e-06      	|  1              	|  1.672e-06      	|  1.3496e-05     	|
# |  [Callback]SaveConfigCallback.on_test_start                                                                                                                       	|  1.5979e-06     	|  1              	|  1.5979e-06     	|  1.2898e-05     	|
# |  [LightningModule]FlowModel.on_test_batch_start                                                                                                                   	|  1.559e-06      	|  1              	|  1.559e-06      	|  1.2584e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start      	|  1.5399e-06     	|  1              	|  1.5399e-06     	|  1.243e-05      	|
# |  [Callback]CrossMatchStatistics.on_load_checkpoint                                                                                                                	|  1.529e-06      	|  1              	|  1.529e-06      	|  1.2342e-05     	|
# |  [Callback]SaveFITS.setup                                                                                                                                         	|  1.502e-06      	|  1              	|  1.502e-06      	|  1.2124e-05     	|
# |  [Callback]PlotMollview.on_test_epoch_start                                                                                                                       	|  1.498e-06      	|  1              	|  1.498e-06      	|  1.2092e-05     	|
# |  [Callback]LearningRateMonitor.on_test_epoch_start                                                                                                                	|  1.495e-06      	|  1              	|  1.495e-06      	|  1.2068e-05     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                               	|  1.4399e-06     	|  1              	|  1.4399e-06     	|  1.1623e-05     	|
# |  [Callback]SaveConfigCallback.on_test_batch_start                                                                                                                 	|  1.433e-06      	|  1              	|  1.433e-06      	|  1.1567e-05     	|
# |  [Callback]PlotCorner.on_test_epoch_end                                                                                                                           	|  1.424e-06      	|  1              	|  1.424e-06      	|  1.1494e-05     	|
# |  [Callback]SaveInjectionParameters.on_test_start                                                                                                                  	|  1.393e-06      	|  1              	|  1.393e-06      	|  1.1244e-05     	|
# |  [Callback]PlotMollview.on_test_start                                                                                                                             	|  1.392e-06      	|  1              	|  1.392e-06      	|  1.1236e-05     	|
# |  [Callback]SaveWandbUrl.on_test_batch_end                                                                                                                         	|  1.377e-06      	|  1              	|  1.377e-06      	|  1.1115e-05     	|
# |  [Callback]CrossMatchStatistics.on_test_epoch_start                                                                                                               	|  1.355e-06      	|  1              	|  1.355e-06      	|  1.0937e-05     	|
# |  [Callback]SaveConfigCallback.teardown                                                                                                                            	|  1.303e-06      	|  1              	|  1.303e-06      	|  1.0518e-05     	|
# |  [Callback]ProbProbPlot.on_test_start                                                                                                                             	|  1.3029e-06     	|  1              	|  1.3029e-06     	|  1.0517e-05     	|
# |  [Callback]SaveWandbUrl.on_test_batch_start                                                                                                                       	|  1.232e-06      	|  1              	|  1.232e-06      	|  9.9448e-06     	|
# |  [Callback]PlotCorner.on_test_epoch_start                                                                                                                         	|  1.2279e-06     	|  1              	|  1.2279e-06     	|  9.9119e-06     	|
# |  [Callback]SaveConfigCallback.on_test_end                                                                                                                         	|  1.216e-06      	|  1              	|  1.216e-06      	|  9.8151e-06     	|
# |  [Callback]SaveConfigCallback.on_test_batch_end                                                                                                                   	|  1.2e-06        	|  1              	|  1.2e-06        	|  9.6864e-06     	|
# |  [Callback]PlotCorner.on_test_start                                                                                                                               	|  1.198e-06      	|  1              	|  1.198e-06      	|  9.6704e-06     	|
# |  [Callback]SaveFITS.on_test_batch_start                                                                                                                           	|  1.1941e-06     	|  1              	|  1.1941e-06     	|  9.6384e-06     	|
# |  [Callback]ProbProbPlot.setup                                                                                                                                     	|  1.176e-06      	|  1              	|  1.176e-06      	|  9.4928e-06     	|
# |  [Callback]SaveFITS.on_test_start                                                                                                                                 	|  1.166e-06      	|  1              	|  1.166e-06      	|  9.412e-06      	|
# |  [Callback]PlotMollview.setup                                                                                                                                     	|  1.152e-06      	|  1              	|  1.152e-06      	|  9.2992e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start	|  1.147e-06      	|  1              	|  1.147e-06      	|  9.2588e-06     	|
# |  [Callback]PlotMollview.on_test_epoch_end                                                                                                                         	|  1.143e-06      	|  1              	|  1.143e-06      	|  9.2259e-06     	|
# |  [Callback]SaveWandbUrl.on_test_end                                                                                                                               	|  1.141e-06      	|  1              	|  1.141e-06      	|  9.2099e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown           	|  1.1179e-06     	|  1              	|  1.1179e-06     	|  9.0239e-06     	|
# |  [Callback]SaveFITS.on_test_end                                                                                                                                   	|  1.0961e-06     	|  1              	|  1.0961e-06     	|  8.8472e-06     	|
# |  [Callback]PlotMollview.on_test_end                                                                                                                               	|  1.0921e-06     	|  1              	|  1.0921e-06     	|  8.8153e-06     	|
# |  [Callback]CrossMatchStatistics.on_test_start                                                                                                                     	|  1.0909e-06     	|  1              	|  1.0909e-06     	|  8.8059e-06     	|
# |  [Callback]PlotCorner.setup                                                                                                                                       	|  1.0771e-06     	|  1              	|  1.0771e-06     	|  8.6941e-06     	|
# |  [Callback]PlotCorner.on_test_batch_start                                                                                                                         	|  1.0739e-06     	|  1              	|  1.0739e-06     	|  8.6687e-06     	|
# |  [LightningModule]FlowModel.teardown                                                                                                                              	|  1.07e-06       	|  1              	|  1.07e-06       	|  8.6367e-06     	|
# |  [Callback]PlotMollview.teardown                                                                                                                                  	|  1.058e-06      	|  1              	|  1.058e-06      	|  8.5399e-06     	|
# |  [Callback]SaveInjectionParameters.on_test_batch_start                                                                                                            	|  1.055e-06      	|  1              	|  1.055e-06      	|  8.5155e-06     	|
# |  [Callback]ProbProbPlot.on_test_batch_start                                                                                                                       	|  1.0499e-06     	|  1              	|  1.0499e-06     	|  8.4751e-06     	|
# |  [Callback]PlotMollview.on_test_batch_start                                                                                                                       	|  1.047e-06      	|  1              	|  1.047e-06      	|  8.4516e-06     	|
# |  [Callback]ProbProbPlot.on_test_end                                                                                                                               	|  1.0449e-06     	|  1              	|  1.0449e-06     	|  8.4347e-06     	|
# |  [Callback]SaveInjectionParameters.setup                                                                                                                          	|  1.038e-06      	|  1              	|  1.038e-06      	|  8.3783e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end        	|  1.0279e-06     	|  1              	|  1.0279e-06     	|  8.2975e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start	|  9.8906e-07     	|  1              	|  9.8906e-07     	|  7.9836e-06     	|
# |  [Callback]SaveWandbUrl.on_test_epoch_end                                                                                                                         	|  9.7393e-07     	|  1              	|  9.7393e-07     	|  7.8615e-06     	|
# |  [Callback]ProbProbPlot.on_test_epoch_start                                                                                                                       	|  9.6904e-07     	|  1              	|  9.6904e-07     	|  7.822e-06      	|
# |  [Callback]ProbProbPlot.on_test_batch_end                                                                                                                         	|  9.6508e-07     	|  1              	|  9.6508e-07     	|  7.7901e-06     	|
# |  [Callback]CrossMatchStatistics.setup                                                                                                                             	|  9.4797e-07     	|  1              	|  9.4797e-07     	|  7.6519e-06     	|
# |  [Callback]SaveConfigCallback.on_test_epoch_end                                                                                                                   	|  9.4704e-07     	|  1              	|  9.4704e-07     	|  7.6444e-06     	|
# |  [Callback]SaveInjectionParameters.on_test_end                                                                                                                    	|  9.3202e-07     	|  1              	|  9.3202e-07     	|  7.5232e-06     	|
# |  [Callback]PlotCorner.teardown                                                                                                                                    	|  9.2899e-07     	|  1              	|  9.2899e-07     	|  7.4988e-06     	|
# |  [Callback]CrossMatchStatistics.teardown                                                                                                                          	|  9.2702e-07     	|  1              	|  9.2702e-07     	|  7.4828e-06     	|
# |  [Callback]SaveConfigCallback.on_test_epoch_start                                                                                                                 	|  9.2201e-07     	|  1              	|  9.2201e-07     	|  7.4424e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                                      	|  9.1805e-07     	|  1              	|  9.1805e-07     	|  7.4104e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                  	|  9.17e-07       	|  1              	|  9.17e-07       	|  7.402e-06      	|
# |  [Callback]SaveWandbUrl.teardown                                                                                                                                  	|  8.8592e-07     	|  1              	|  8.8592e-07     	|  7.1511e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                       	|  8.8103e-07     	|  1              	|  8.8103e-07     	|  7.1116e-06     	|
# |  [Callback]ProbProbPlot.teardown                                                                                                                                  	|  8.7905e-07     	|  1              	|  8.7905e-07     	|  7.0956e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                    	|  8.6206e-07     	|  1              	|  8.6206e-07     	|  6.9584e-06     	|
# |  [Callback]PlotCorner.on_test_end                                                                                                                                 	|  8.6206e-07     	|  1              	|  8.6206e-07     	|  6.9584e-06     	|
# |  [Callback]CrossMatchStatistics.on_test_end                                                                                                                       	|  8.4599e-07     	|  1              	|  8.4599e-07     	|  6.8288e-06     	|
# |  [Callback]CrossMatchStatistics.on_test_batch_start                                                                                                               	|  8.3901e-07     	|  1              	|  8.3901e-07     	|  6.7724e-06     	|
# |  [Callback]SaveWandbUrl.on_test_epoch_start                                                                                                                       	|  8.34e-07       	|  1              	|  8.34e-07       	|  6.732e-06      	|
# |  [Callback]SaveInjectionParameters.teardown                                                                                                                       	|  8.34e-07       	|  1              	|  8.34e-07       	|  6.732e-06      	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                         	|  8.2399e-07     	|  1              	|  8.2399e-07     	|  6.6512e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Set parameters to prepare for generating sine Gaussian waveforms

# %%
# Desired duration of time-domain waveform
waveform_duration = 7
# Sample rate of all the data we'll be using today
sample_rate = 2048

nyquist = sample_rate / 2
num_samples = int(waveform_duration * sample_rate)
num_freqs = num_samples // 2 + 1

# %% [markdown]
# ### Define priors for waveform

# %%
from ml4gw.distributions import LogUniform
from torch.distributions import Uniform
from ml4gw.waveforms import SineGaussian
import numpy as np

min_freq = 32
max_freq = 1024

min_qual = 25
max_qual = 75

min_hrss = 1e-21
max_hrss = 2e-21

min_phase = 0
max_phase = 2 * np.pi

min_ecc = 0
max_ecc = 0.01

min_dec = -np.pi / 2
max_dec = np.pi / 2

min_psi = 0
max_psi = np.pi

min_phi = 0
max_phi = 2 * np.pi

corner_range = [(min_phase, max_phase), (min_dec, max_dec), (min_psi, max_psi), (min_phi, max_phi)]
# On CPU, keep the number of waveforms around 100. On GPU, you can go higher
num_waveforms = 3
num_packet = 250

param_dict = {
    "frequency": Uniform(min_freq, max_freq, False),
    "quality": Uniform(min_qual, max_qual, False),
    "hrss": Uniform(min_hrss, max_hrss, False),
    "phase": Uniform(min_phase, max_phase, False),
    "eccentricity": Uniform(min_ecc, max_ecc, False),
}

# And then sample from each of those distributions
params = [{
    k: v.sample((num_waveforms, )).cpu() for k, v in param_dict.items()
} for _ in range(num_packet)]

# %%
approximant = SineGaussian(sample_rate, waveform_duration)
cross_waveforms = []
plus_waveforms = []

for param in params:
    cross, plus = approximant(**param)
    cross = cross.mean(0).unsqueeze(0)
    plus = plus.mean(0).unsqueeze(0)
    cross_waveforms.append(cross)
    plus_waveforms.append(plus)
cross = torch.cat(cross_waveforms, dim=0)
plus = torch.cat(plus_waveforms, dim=0)

freq = []
qual = []
hrss = []
phase = []
ecc = []

for param in params:
    freq.append(param['frequency'].mean(0))
    qual.append(param['quality'].mean(0))
    hrss.append(param['hrss'].mean(0))
    phase.append(param['phase'].mean(0))
    ecc.append(param['eccentricity'].mean(0))

params_packet = {'frequency': torch.tensor(freq), 'quality': torch.tensor(qual), 'hrss': torch.tensor(hrss), 'phase': torch.tensor(phase), 'eccentricity': torch.tensor(ecc)}


times = torch.arange(0, waveform_duration, 1 / sample_rate)
# Calling the approximant with the frequency array, reference frequency, and waveform parameters
# returns the cross and plus polarizations
print(cross.shape, plus.shape)
# Out:
# torch.Size([250, 14336]) torch.Size([250, 14336])

# %%
# Set up data coming from both detectors
from ml4gw.gw import get_ifo_geometry, compute_observed_strain

# The interferometer geometry for V1 and K1 are also in ml4gw
ifos = ["H1", "L1"]
tensors, vertices = get_ifo_geometry(*ifos)

# %%
datamodule = cli.datamodule
model = cli.model
model.eval();

# %% [markdown]
# ### Load in background data

# %%
waveforms_dataloader, background_dataloader = datamodule.test_dataloader().datasets
background_data = next(iter(background_dataloader))
background_data = background_data[0][0].repeat(num_packet, 1, 1)
print(background_data.shape)
# Out:
# torch.Size([250, 2, 38912])

# %% [markdown]
# ### Inject sg waveforms into the background data and use amplfi to predict waveform parameters

# %%
# keep sky location and ecc const
strain, asds, parameters, snrs = datamodule.inject(background_data, cross, plus, params_packet)
batch = []
for s, a, p, sn in zip(strain, asds, parameters, snrs):
    batch.append((s.unsqueeze(0), a.unsqueeze(0), p.unsqueeze(0), sn.unsqueeze(0)))
print(strain.shape)
print(asds.shape)
print(parameters.shape)
print(snrs.shape)
# Out:
# torch.Size([250, 2, 10240])
# torch.Size([250, 2, 4995])
# torch.Size([250, 4])
# torch.Size([250])

# %%
results = []
i = 0
for b in batch:
    result = model.test_step(b, _)
    results.append(result)
    i += 1
    if i % 50 == 0:
        print(f"{i} out of {num_packet}")
# Out:
# 2025-12-08 12:49:48,876 - FlowModel - INFO - Removed 86/10000 total samples outside of prior range
# 2025-12-08 12:49:52,723 - FlowModel - INFO - Removed 28/10000 total samples outside of prior range
# 2025-12-08 12:49:56,513 - FlowModel - INFO - Removed 74/10000 total samples outside of prior range
# 2025-12-08 12:50:00,384 - FlowModel - INFO - Removed 15/10000 total samples outside of prior range
# 2025-12-08 12:50:04,201 - FlowModel - INFO - Removed 19/10000 total samples outside of prior range
# 2025-12-08 12:50:08,059 - FlowModel - INFO - Removed 15/10000 total samples outside of prior range
# 2025-12-08 12:50:11,781 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:50:15,537 - FlowModel - INFO - Removed 16/10000 total samples outside of prior range
# 2025-12-08 12:50:19,417 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:50:23,287 - FlowModel - INFO - Removed 18/10000 total samples outside of prior range
# 2025-12-08 12:50:26,911 - FlowModel - INFO - Removed 12/10000 total samples outside of prior range
# 2025-12-08 12:50:30,731 - FlowModel - INFO - Removed 15/10000 total samples outside of prior range
# 2025-12-08 12:50:34,620 - FlowModel - INFO - Removed 20/10000 total samples outside of prior range
# 2025-12-08 12:50:38,626 - FlowModel - INFO - Removed 18/10000 total samples outside of prior range
# 2025-12-08 12:50:42,450 - FlowModel - INFO - Removed 15/10000 total samples outside of prior range
# 2025-12-08 12:50:46,293 - FlowModel - INFO - Removed 24/10000 total samples outside of prior range
# 2025-12-08 12:50:50,212 - FlowModel - INFO - Removed 22/10000 total samples outside of prior range
# 2025-12-08 12:50:53,889 - FlowModel - INFO - Removed 18/10000 total samples outside of prior range
# 2025-12-08 12:50:57,932 - FlowModel - INFO - Removed 20/10000 total samples outside of prior range
# 2025-12-08 12:51:01,864 - FlowModel - INFO - Removed 10/10000 total samples outside of prior range
# 2025-12-08 12:51:05,840 - FlowModel - INFO - Removed 20/10000 total samples outside of prior range
# 2025-12-08 12:51:09,843 - FlowModel - INFO - Removed 19/10000 total samples outside of prior range
# 2025-12-08 12:51:13,741 - FlowModel - INFO - Removed 19/10000 total samples outside of prior range
# 2025-12-08 12:51:17,569 - FlowModel - INFO - Removed 15/10000 total samples outside of prior range
# 2025-12-08 12:51:21,345 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:51:25,189 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:51:29,021 - FlowModel - INFO - Removed 13/10000 total samples outside of prior range
# 2025-12-08 12:51:32,853 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:51:36,798 - FlowModel - INFO - Removed 16/10000 total samples outside of prior range
# 2025-12-08 12:55:56,377 - FlowModel - INFO - Removed 15/10000 total samples outside of prior range
# 2025-12-08 12:56:00,261 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:56:04,355 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:56:08,390 - FlowModel - INFO - Removed 8/10000 total samples outside of prior range
# 2025-12-08 12:56:12,460 - FlowModel - INFO - Removed 17/10000 total samples outside of prior range
# 100 out of 250
# 2025-12-08 12:56:16,556 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 12:56:20,582 - FlowModel - INFO - Removed 23/10000 total samples outside of prior range
# 2025-12-08 12:56:24,539 - FlowModel - INFO - Removed 13/10000 total samples outside of prior range
# 2025-12-08 12:56:28,628 - FlowModel - INFO - Removed 8/10000 total samples outside of prior range
# 2025-12-08 12:56:32,405 - FlowModel - INFO - Removed 15/10000 total samples outside of prior range
# 2025-12-08 12:56:36,422 - FlowModel - INFO - Removed 676/10000 total samples outside of prior range
# 2025-12-08 12:56:40,351 - FlowModel - INFO - Removed 45/10000 total samples outside of prior range
# 2025-12-08 12:56:44,618 - FlowModel - INFO - Removed 21/10000 total samples outside of prior range
# 2025-12-08 12:56:48,527 - FlowModel - INFO - Removed 9/10000 total samples outside of prior range
# 2025-12-08 12:56:52,359 - FlowModel - INFO - Removed 11/10000 total samples outside of prior range
# 2025-12-08 12:56:56,156 - FlowModel - INFO - Removed 9/10000 total samples outside of prior range
# 2025-12-08 12:57:00,027 - FlowModel - INFO - Removed 17/10000 total samples outside of prior range
# 2025-12-08 12:57:03,897 - FlowModel - INFO - Removed 16/10000 total samples outside of prior range
# 2025-12-08 12:57:07,819 - FlowModel - INFO - Removed 16/10000 total samples outside of prior range
# 2025-12-08 12:57:11,607 - FlowModel - INFO - Removed 32/10000 total samples outside of prior range
# 2025-12-08 12:57:15,484 - FlowModel - INFO - Removed 7/10000 total samples outside of prior range
# 2025-12-08 12:57:19,269 - FlowModel - INFO - Removed 18/10000 total samples outside of prior range
# 2025-12-08 12:57:22,867 - FlowModel - INFO - Removed 24/10000 total samples outside of prior range
# 2025-12-08 12:57:26,941 - FlowModel - INFO - Removed 10/10000 total samples outside of prior range
# 2025-12-08 12:57:30,800 - FlowModel - INFO - Removed 50/10000 total samples outside of prior range
# 2025-12-08 12:57:34,763 - FlowModel - INFO - Removed 12/10000 total samples outside of prior range
# 2025-12-08 12:57:38,790 - FlowModel - INFO - Removed 22/10000 total samples outside of prior range
# 2025-12-08 12:57:42,397 - FlowModel - INFO - Removed 17/10000 total samples outside of prior range
# 2025-12-08 12:57:46,319 - FlowModel - INFO - Removed 27/10000 total samples outside of prior range
# 2025-12-08 12:57:50,171 - FlowModel - INFO - Removed 25/10000 total samples outside of prior range
# 2025-12-08 12:57:54,264 - FlowModel - INFO - Removed 6/10000 total samples outside of prior range
# 2025-12-08 12:57:58,274 - FlowModel - INFO - Removed 19/10000 total samples outside of prior range
# 2025-12-08 12:58:02,355 - FlowModel - INFO - Removed 18/10000 total samples outside of prior range
# 2025-12-08 13:04:40,379 - FlowModel - INFO - Removed 16/10000 total samples outside of prior range
# 2025-12-08 13:04:44,379 - FlowModel - INFO - Removed 13/10000 total samples outside of prior range
# 2025-12-08 13:04:48,512 - FlowModel - INFO - Removed 20/10000 total samples outside of prior range
# 2025-12-08 13:04:52,598 - FlowModel - INFO - Removed 17/10000 total samples outside of prior range
# 2025-12-08 13:04:56,703 - FlowModel - INFO - Removed 13/10000 total samples outside of prior range
# 2025-12-08 13:05:00,789 - FlowModel - INFO - Removed 26/10000 total samples outside of prior range
# 2025-12-08 13:05:04,770 - FlowModel - INFO - Removed 11/10000 total samples outside of prior range
# 2025-12-08 13:05:08,788 - FlowModel - INFO - Removed 10/10000 total samples outside of prior range
# 2025-12-08 13:05:12,825 - FlowModel - INFO - Removed 16/10000 total samples outside of prior range
# 2025-12-08 13:05:16,799 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 13:05:20,637 - FlowModel - INFO - Removed 21/10000 total samples outside of prior range
# 2025-12-08 13:05:24,700 - FlowModel - INFO - Removed 17/10000 total samples outside of prior range
# 2025-12-08 13:05:28,461 - FlowModel - INFO - Removed 12/10000 total samples outside of prior range
# 2025-12-08 13:05:32,410 - FlowModel - INFO - Removed 12/10000 total samples outside of prior range
# 2025-12-08 13:05:36,368 - FlowModel - INFO - Removed 25/10000 total samples outside of prior range
# 2025-12-08 13:05:40,375 - FlowModel - INFO - Removed 12/10000 total samples outside of prior range
# 2025-12-08 13:05:44,230 - FlowModel - INFO - Removed 17/10000 total samples outside of prior range
# 2025-12-08 13:05:48,148 - FlowModel - INFO - Removed 18/10000 total samples outside of prior range
# 2025-12-08 13:05:52,080 - FlowModel - INFO - Removed 19/10000 total samples outside of prior range
# 2025-12-08 13:05:56,165 - FlowModel - INFO - Removed 20/10000 total samples outside of prior range
# 2025-12-08 13:06:00,098 - FlowModel - INFO - Removed 22/10000 total samples outside of prior range
# 2025-12-08 13:06:04,226 - FlowModel - INFO - Removed 16/10000 total samples outside of prior range
# 2025-12-08 13:06:08,296 - FlowModel - INFO - Removed 14/10000 total samples outside of prior range
# 2025-12-08 13:06:12,301 - FlowModel - INFO - Removed 24/10000 total samples outside of prior range
# 250 out of 250

# %%
import bilby

bilby.result.make_pp_plot(results)
# Out:
# 14:18 bilby INFO    : Key: KS-test p-value
# 14:18 bilby INFO    : phase: 1.4059598194001543e-10
# 14:18 bilby INFO    : dec: 2.4550429555971516e-10
# 14:18 bilby INFO    : psi: 0.32076469920498263
# 14:18 bilby INFO    : phi: 5.536443974066669e-11
# 14:18 bilby INFO    : Combined p-value: 3.592250742289624e-26
# (<Figure size 640x480 with 1 Axes>,
#  pvals(combined_pvalue=3.592250742289624e-26, pvalues=[1.4059598194001543e-10, 2.4550429555971516e-10, 0.32076469920498263, 5.536443974066669e-11], names=['phase', 'dec', 'psi', 'phi']))

# %% [markdown]
# ### Corner Plot

# %%
import pandas as pd
params_df = pd.DataFrame(params)
params_df['dec'] = np.full(len(params_df), params_packet['dec'].item())
params_df['psi'] = np.full(len(params_df), params_packet['psi'].item())
params_df['phi'] = np.full(len(params_df), params_packet['phi'].item())
params_df = params_df[["phase", "dec", "psi", "phi"]]

# %%
import corner
param_vals = np.array([v.item() for k, v in params_packet.items()])
fig = result.plot_corner(save=False, levels=(0.5, 0.9), range = corner_range);
for vals in params_df.to_numpy():
    corner.overplot_lines(fig, vals, color='r')
plt.savefig('sg_packet_corner_packet_3.png')

# %% [markdown]
# ### Take the average of the 10000 samples generated from amplfi to generate a single waveform and see how this compares to waveform generated using actual values

# %%
posterior = result.posterior
post = {key: torch.tensor([posterior[key].mean()]) for key in posterior.keys()
        if key in param_dict.keys()}

# Phase of the two waveforms do not match up unless I set the phase for the posterior to be the
# same as the prior
# post['phase'] = params['phase']

# %%
post['frequency'] = params_packet['frequency']
post['quality'] = params_packet['quality']
post['hrss'] = params_packet['hrss']
post['eccentricity'] = params_packet['eccentricity']

# %%
post
# Out:
# {'phase': tensor([3.1295]),
#  'frequency': tensor(154.7564),
#  'quality': tensor(53.7245),
#  'hrss': tensor(1.3663e-21),
#  'eccentricity': tensor(0.0065)}

# %%
from scipy.stats import probplot
num_params = len(posterior.keys()[:-2])
fig, axes = plt.subplots(2, 2, sharex=True, figsize = (10, 10))
post_plot = posterior.to_numpy().T
key = posterior.keys()
probplot(post_plot[0], plot=axes[0, 0])
probplot(post_plot[1], plot=axes[0, 1])
probplot(post_plot[2], plot=axes[1, 0])
probplot(post_plot[3], plot=axes[1, 1])
axes[0, 0].set_title(key[0])
axes[0, 1].set_title(key[1])
axes[1, 0].set_title(key[2])
axes[1, 1].set_title(key[3])
plt.tight_layout()
plt.savefig('sg_packet_qq_packet_3.png')

# %% [markdown]
# ### Generate waveforms from prior values

# %%
waveforms = compute_observed_strain(
    dec=torch.tensor([params_packet['dec']]),
    psi=torch.tensor([params_packet['psi']]),
    phi=torch.tensor([params_packet['phi']]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross,
    plus=plus,
)

# %% [markdown]
# ### Generate waveforms from average of posterior values

# %%
cross_pred, plus_pred = approximant(**post)

waveforms_pred = compute_observed_strain(
    dec=torch.tensor([posterior['dec'].mean()]),
    psi=torch.tensor([posterior['psi'].mean()]),
    phi=torch.tensor([posterior['phi'].mean()]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross_pred,
    plus=plus_pred,
)
print(waveforms_pred.shape)
# Out:
# torch.Size([1, 2, 14336])

# %%
mean_waveform_pred = waveforms_pred.mean(0)
print(mean_waveform_pred.shape)
print(waveforms.shape)
# Out:
# torch.Size([2, 14336])
# torch.Size([1, 2, 14336])

# %% [markdown]
# ### Plot waveforms together

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=True, figsize=(15, 7))
ax[0].plot(times, waveforms[0, 0].cpu(), color='k', label="original", alpha=0.5)
ax[0].plot(times, mean_waveform_pred[0].cpu (), color='r', label="predicted", alpha=0.5)
ax[1].plot(times, waveforms[0, 1].cpu(), color='k', alpha=0.5)
ax[1].plot(times, mean_waveform_pred[1].cpu(), color='r', alpha=0.5)
ax[1].set_xlabel("Time (s)")
ax[0].set_ylabel("Strain H1")
ax[1].set_ylabel("Strain L1")
ax[0].legend()
ax[1].set_xlim(3, 4)
plt.show()

# %% [markdown]
# ### Try generating all 10000 waveforms first, then taking the average of all of the waveforms

# %%
posterior = result.posterior
post = {key: torch.tensor([posterior[key]]) for key in posterior.keys()
        if key in param_dict.keys()}

# %%
post['frequency'] = torch.full([len(post['phase'])], params_packet['frequency'].item())
post['quality'] = torch.full([len(post['phase'])], params_packet['quality'].item())
post['hrss'] = torch.full([len(post['phase'])], params_packet['hrss'].item())
post['eccentricity'] = torch.full([len(post['phase'])], params_packet['eccentricity'].item())

# %%
post
# Out:
# {'phase': tensor([[5.4137, 0.6317, 1.8628,  ..., 5.2332, 4.8908, 6.0805]]),
#  'frequency': tensor([154.7564]),
#  'quality': tensor([53.7245]),
#  'hrss': tensor([1.3663e-21]),
#  'eccentricity': tensor([0.0065])}

# %%
cross_pred, plus_pred = approximant(**post)

waveforms_pred = compute_observed_strain(
    dec=torch.tensor([posterior['dec']]),
    psi=torch.tensor([posterior['psi']]),
    phi=torch.tensor([posterior['phi']]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross_pred,
    plus=plus_pred,
)
print(waveforms_pred.shape)
# Out:
# torch.Size([9972, 2, 14336])

# %%
percentile_waveform_pred = np.percentile(waveforms_pred.cpu(), [5, 95], axis=0)
print(percentile_waveform_pred.shape)
print(mean_waveform_pred.shape)
print(waveforms.shape)
# Out:
# (2, 2, 14336)
# torch.Size([2, 14336])
# torch.Size([1, 2, 14336])

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=True, figsize=(10, 5))
ax[0].plot(times, waveforms[0, 0].cpu(), color='k', alpha=0.5)
ax[0].fill_between(times, percentile_waveform_pred[0, 0], percentile_waveform_pred[1, 0], alpha=0.5)
ax[1].plot(times, waveforms[0, 1].cpu(), color='k', alpha=0.5)
ax[1].fill_between(times, percentile_waveform_pred[0, 1], percentile_waveform_pred[1, 1], alpha=0.5)
ax[1].set_xlabel("Time (s)")
ax[0].set_ylabel("Strain H1")
ax[1].set_ylabel("Strain L1")
ax[1].set_xlim(3, 4)
plt.tight_layout()
# plt.savefig("./images/sg_packet.png")
plt.show()

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=(15, 7))
wave_ave = 0
num_waves = 1000
ip = len(waveforms_pred) // num_waves + 1
for wave in waveforms_pred[::ip, 0, :]:
    ax[0].plot(times, wave)
    wave_ave += wave
wave_ave /= num_waves
ax[1].plot(times, wave_ave)
ax[2].plot(times, waveforms[0, 0])
ax[0].set_xlim(3.4, 3.6)
plt.show()

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=(15, 7))
wave_ave = 0
ip = len(waveforms_pred) // num_waves + 1
for wave in waveforms_pred[::ip, 1, :]:
    ax[0].plot(times, wave)
    wave_ave += wave
wave_ave /= num_waves
ax[1].plot(times, wave_ave)
ax[2].plot(times, waveforms[0, 1])
# ax[0].set_xlim(3.4, 3.6)
plt.show()
