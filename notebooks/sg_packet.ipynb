# %%
import os
import importlib
import sys
import torch
import matplotlib.pyplot as plt
import pandas as pd

device = torch.device('cuda') if torch.cuda.is_available() else 'cpu'
os.environ['AMPLFI_OUTDIR'] = '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg'
os.environ['AMPLFI_DATADIR'] = '/home/aframe/dev/o4_llpic/amplfi/hl/data'

# %%
module_path = "/home/jack.redepenning/amplfi_dir/amplfi/amplfi/__init__.py"
module_name = "amplfi"

# %%
spec = importlib.util.spec_from_file_location(module_name, module_path)
amplfi = importlib.util.module_from_spec(spec)
sys.modules[module_name] = amplfi
spec.loader.exec_module(amplfi)
print(amplfi.__file__)  # Should now point to your local repo
# Out:
# /home/jack.redepenning/amplfi_dir/amplfi/amplfi/__init__.py

# %%
ckpt_path = "/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt"
config_path = "/home/jack.redepenning/amplfi_dir/amplfi/runs/sg_sky_loc/sg.yaml"
param_path = "/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg/parameters.hdf5"

# %%
from amplfi.train.data.datasets.base import AmplfiDataset
from amplfi.train.models.base import AmplfiModel
from amplfi.train.cli.flow import AmplfiFlowCLI

cli = AmplfiFlowCLI(
        AmplfiModel,
        AmplfiDataset,
        subclass_mode_model=True,
        subclass_mode_data=True,
        save_config_kwargs={"overwrite": True},
        seed_everything_default=101588,
        args=[
        "test",             # Subcommand
        "--config", config_path,
        "--ckpt_path", ckpt_path,
        ]
)
# Out:
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/lightning/pytorch/cli.py:528: LightningCLI's args parameter is intended to run from within Python like if it were from the command line. To prevent mistakes it is not recommended to provide both args and command line arguments, got: sys.argv[1:]=['--f=/run/user/48090/jupyter/runtime/kernel-v3eacfcfe43781f56fd5dca04b47e56c2ddc998a30.json'], args=['test', '--config', '/home/jack.redepenning/amplfi_dir/amplfi/runs/sg_sky_loc/sg.yaml', '--ckpt_path', '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt'].
# Seed set to 101588
# Seed set to 101588
# 2025-08-07 10:56:07,080 - root - INFO - Downloading data to /home/aframe/dev/o4_llpic/amplfi/hl/data
# Trainer will use only 1 of 4 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=4)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: redep028 (redep028-university-of-minnesota). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg/train_logs/wandb/run-20250807_105607-jsdgvlpb</code>
# Syncing run <strong><a href='https://wandb.ai/redep028-university-of-minnesota/amplfi/runs/jsdgvlpb' target="_blank">gentle-sunset-194</a></strong> to <a href='https://wandb.ai/redep028-university-of-minnesota/amplfi' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/redep028-university-of-minnesota/amplfi' target="_blank">https://wandb.ai/redep028-university-of-minnesota/amplfi</a>
#  View run at <a href='https://wandb.ai/redep028-university-of-minnesota/amplfi/runs/jsdgvlpb' target="_blank">https://wandb.ai/redep028-university-of-minnesota/amplfi/runs/jsdgvlpb</a>
# 2025-08-07 10:56:08,665 - FlowDataset - INFO - Setting up data for stage TrainerFn.TESTING
# 2025-08-07 10:56:08,666 - FlowDataset - INFO - Using 83 files with a total duration of 9.444 days for testing
# 2025-08-07 10:56:08,671 - FlowDataset - INFO - Inferred sample rate of 2048.0 Hz
# 2025-08-07 10:56:08,674 - FlowDataset - INFO - Loaded 1 waveforms for testing
# 2025-08-07 10:56:08,675 - FlowDataset - INFO - Building torch Modules and transferring to device
# 2025-08-07 10:56:08,677 - FlowDataset - INFO - Using pre-fit standard scaler
# Restoring states from the checkpoint path at /home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:362: The dirpath has changed from '/projects/bcse/jredepenning//amplfi-outdir/run5/sg_sky_loc/train_logs/amplfi/re0zo7ef/checkpoints' to '/home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/sg/train_logs/amplfi/jsdgvlpb/checkpoints', therefore `best_model_score`, `kth_best_model_path`, `kth_value`, `last_model_path` and `best_k_models` won't be reloaded. Only `best_model_path` will be reloaded.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Loaded model weights from the checkpoint at /home/jack.redepenning/amplfi_dir/amplfi-outdir/runs/finished_model/sg_sky_loc/best.ckpt
# Testing: |          | 0/? [00:00<?, ?it/s]
# 2025-08-07 10:56:13,638 - FlowModel - INFO - Removed 20/10000 total samples outside of prior range
# 2025-08-07 10:56:15,905 - FlowModel - INFO - Making PP plot
# 10:56 bilby INFO    : Key: KS-test p-value
# 10:56 bilby INFO    : phase: 0.7294589178356712
# 10:56 bilby INFO    : dec: 0.9144288577154309
# 10:56 bilby INFO    : psi: 0.6741482965931864
# 10:56 bilby INFO    : phi: 0.9068136272545089
# 10:56 bilby INFO    : Combined p-value: 0.9866874185229559
# Crossmatching skymaps:   0%|          | 0/1 [00:00<?, ?it/s]
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/ligo/skymap/postprocess/crossmatch.py:395: RuntimeWarning: invalid value encountered in subtract
#   contour_dists = (hi - lo).tolist()
# /home/jack.redepenning/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/ligo/skymap/postprocess/crossmatch.py:414: RuntimeWarning: invalid value encountered in divide
#   dP_dV = dP / dV
# TEST Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                           	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                            	|  -              	|  131            	|  20.787         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Callback]CrossMatchStatistics.on_test_epoch_end                                                                                                                 	|  10.823         	|  1              	|  10.823         	|  52.064         	|
# |  [Callback]PlotCorner.on_test_batch_end                                                                                                                           	|  1.4369         	|  1              	|  1.4369         	|  6.9126         	|
# |  [Callback]ProbProbPlot.on_test_epoch_end                                                                                                                         	|  1.0752         	|  1              	|  1.0752         	|  5.1723         	|
# |  [Callback]SaveConfigCallback.setup                                                                                                                               	|  1.0655         	|  1              	|  1.0655         	|  5.1257         	|
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                         	|  0.8553         	|  1              	|  0.8553         	|  4.1146         	|
# |  [Callback]PlotMollview.on_test_batch_end                                                                                                                         	|  0.54474        	|  1              	|  0.54474        	|  2.6206         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                   	|  0.39405        	|  1              	|  0.39405        	|  1.8957         	|
# |  [LightningDataModule]FlowDataset.on_after_batch_transfer                                                                                                         	|  0.39316        	|  1              	|  0.39316        	|  1.8914         	|
# |  [Callback]SaveFITS.on_test_batch_end                                                                                                                             	|  0.27071        	|  1              	|  0.27071        	|  1.3023         	|
# |  [LightningDataModule]FlowDataset.setup                                                                                                                           	|  0.2507         	|  1              	|  0.2507         	|  1.206          	|
# |  [LightningDataModule]FlowDataset.test_dataloader                                                                                                                 	|  0.22557        	|  1              	|  0.22557        	|  1.0851         	|
# |  [Callback]SaveInjectionParameters.on_test_epoch_start                                                                                                            	|  0.21374        	|  1              	|  0.21374        	|  1.0283         	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                          	|  0.014471       	|  1              	|  0.014471       	|  0.069615       	|
# |  [_EvaluationLoop].test_next                                                                                                                                      	|  0.0051246      	|  1              	|  0.0051246      	|  0.024653       	|
# |  [Callback]SaveInjectionParameters.on_test_epoch_end                                                                                                              	|  0.0049951      	|  1              	|  0.0049951      	|  0.02403        	|
# |  [LightningModule]FlowModel.on_test_model_eval                                                                                                                    	|  0.0018719      	|  1              	|  0.0018719      	|  0.009005       	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                                    	|  0.0012822      	|  1              	|  0.0012822      	|  0.0061681      	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                            	|  0.0011958      	|  1              	|  0.0011958      	|  0.0057528      	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                                      	|  0.00078133     	|  1              	|  0.00078133     	|  0.0037587      	|
# |  [LightningModule]FlowModel.transfer_batch_to_device                                                                                                              	|  0.00076096     	|  1              	|  0.00076096     	|  0.0036607      	|
# |  [LightningModule]FlowModel.configure_callbacks                                                                                                                   	|  0.00027249     	|  1              	|  0.00027249     	|  0.0013109      	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup              	|  0.00020532     	|  1              	|  0.00020532     	|  0.00098775     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end  	|  4.7306e-05     	|  1              	|  4.7306e-05     	|  0.00022757     	|
# |  [LightningDataModule]FlowDataset.prepare_data                                                                                                                    	|  2.1312e-05     	|  1              	|  2.1312e-05     	|  0.00010253     	|
# |  [Callback]SaveWandbUrl.on_test_epoch_start                                                                                                                       	|  2.1197e-05     	|  1              	|  2.1197e-05     	|  0.00010197     	|
# |  [Callback]ProbProbPlot.setup                                                                                                                                     	|  1.796e-05      	|  1              	|  1.796e-05      	|  8.6398e-05     	|
# |  [Callback]SaveFITS.on_test_batch_start                                                                                                                           	|  1.6753e-05     	|  1              	|  1.6753e-05     	|  8.0594e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                  	|  1.6408e-05     	|  1              	|  1.6408e-05     	|  7.8934e-05     	|
# |  [Callback]SaveInjectionParameters.on_test_batch_end                                                                                                              	|  1.4693e-05     	|  1              	|  1.4693e-05     	|  7.0684e-05     	|
# |  [LightningModule]FlowModel.on_test_epoch_start                                                                                                                   	|  1.0863e-05     	|  1              	|  1.0863e-05     	|  5.2258e-05     	|
# |  [LightningModule]FlowModel.setup                                                                                                                                 	|  9.9638e-06     	|  1              	|  9.9638e-06     	|  4.7933e-05     	|
# |  [Callback]CrossMatchStatistics.on_test_batch_end                                                                                                                 	|  8.3842e-06     	|  1              	|  8.3842e-06     	|  4.0334e-05     	|
# |  [Callback]LearningRateMonitor.setup                                                                                                                              	|  8.1789e-06     	|  1              	|  8.1789e-06     	|  3.9346e-05     	|
# |  [Callback]LearningRateMonitor.on_test_start                                                                                                                      	|  7.2056e-06     	|  1              	|  7.2056e-06     	|  3.4664e-05     	|
# |  [Callback]LearningRateMonitor.on_load_checkpoint                                                                                                                 	|  5.2252e-06     	|  1              	|  5.2252e-06     	|  2.5137e-05     	|
# |  [Callback]SaveFITS.on_test_epoch_start                                                                                                                           	|  5.1814e-06     	|  1              	|  5.1814e-06     	|  2.4926e-05     	|
# |  [LightningDataModule]FlowDataset.teardown                                                                                                                        	|  5.0957e-06     	|  1              	|  5.0957e-06     	|  2.4514e-05     	|
# |  [Callback]LearningRateMonitor.on_test_epoch_start                                                                                                                	|  5.0422e-06     	|  1              	|  5.0422e-06     	|  2.4256e-05     	|
# |  [Callback]SaveWandbUrl.setup                                                                                                                                     	|  5.0063e-06     	|  1              	|  5.0063e-06     	|  2.4084e-05     	|
# |  [Callback]ModelSummary.setup                                                                                                                                     	|  4.2259e-06     	|  1              	|  4.2259e-06     	|  2.0329e-05     	|
# |  [LightningModule]FlowModel.on_test_epoch_end                                                                                                                     	|  4.1057e-06     	|  1              	|  4.1057e-06     	|  1.9751e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                     	|  4.0499e-06     	|  1              	|  4.0499e-06     	|  1.9483e-05     	|
# |  [Callback]LearningRateMonitor.teardown                                                                                                                           	|  3.9679e-06     	|  1              	|  3.9679e-06     	|  1.9088e-05     	|
# |  [Callback]LearningRateMonitor.on_test_end                                                                                                                        	|  3.9479e-06     	|  1              	|  3.9479e-06     	|  1.8992e-05     	|
# |  [Callback]SaveFITS.on_load_checkpoint                                                                                                                            	|  3.8301e-06     	|  1              	|  3.8301e-06     	|  1.8425e-05     	|
# |  [LightningModule]FlowModel.on_test_batch_end                                                                                                                     	|  3.5027e-06     	|  1              	|  3.5027e-06     	|  1.685e-05      	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                             	|  3.0189e-06     	|  1              	|  3.0189e-06     	|  1.4523e-05     	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                         	|  2.9793e-06     	|  1              	|  2.9793e-06     	|  1.4332e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                       	|  2.9639e-06     	|  1              	|  2.9639e-06     	|  1.4259e-05     	|
# |  [Callback]SaveFITS.on_test_epoch_end                                                                                                                             	|  2.889e-06      	|  1              	|  2.889e-06      	|  1.3898e-05     	|
# |  [Callback]LearningRateMonitor.on_test_batch_start                                                                                                                	|  2.8573e-06     	|  1              	|  2.8573e-06     	|  1.3746e-05     	|
# |  [Callback]LearningRateMonitor.on_test_batch_end                                                                                                                  	|  2.8154e-06     	|  1              	|  2.8154e-06     	|  1.3544e-05     	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                                       	|  2.733e-06      	|  1              	|  2.733e-06      	|  1.3147e-05     	|
# |  [LightningModule]FlowModel.on_load_checkpoint                                                                                                                    	|  2.725e-06      	|  1              	|  2.725e-06      	|  1.3109e-05     	|
# |  [Callback]LearningRateMonitor.on_test_epoch_end                                                                                                                  	|  2.6859e-06     	|  1              	|  2.6859e-06     	|  1.2921e-05     	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                               	|  2.597e-06      	|  1              	|  2.597e-06      	|  1.2493e-05     	|
# |  [Callback]ModelSummary.on_load_checkpoint                                                                                                                        	|  2.3409e-06     	|  1              	|  2.3409e-06     	|  1.1261e-05     	|
# |  [Callback]SaveConfigCallback.on_load_checkpoint                                                                                                                  	|  2.3399e-06     	|  1              	|  2.3399e-06     	|  1.1257e-05     	|
# |  [Callback]TQDMProgressBar.on_load_checkpoint                                                                                                                     	|  2.1723e-06     	|  1              	|  2.1723e-06     	|  1.045e-05      	|
# |  [Callback]CrossMatchStatistics.on_load_checkpoint                                                                                                                	|  2.156e-06      	|  1              	|  2.156e-06      	|  1.0372e-05     	|
# |  [Callback]ProbProbPlot.on_load_checkpoint                                                                                                                        	|  2.0899e-06     	|  1              	|  2.0899e-06     	|  1.0054e-05     	|
# |  [Callback]PlotMollview.on_load_checkpoint                                                                                                                        	|  2.0419e-06     	|  1              	|  2.0419e-06     	|  9.8231e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_load_checkpoint 	|  2.0047e-06     	|  1              	|  2.0047e-06     	|  9.6439e-06     	|
# |  [Callback]SaveWandbUrl.on_load_checkpoint                                                                                                                        	|  1.8948e-06     	|  1              	|  1.8948e-06     	|  9.1152e-06     	|
# |  [Callback]PlotCorner.on_load_checkpoint                                                                                                                          	|  1.844e-06      	|  1              	|  1.844e-06      	|  8.871e-06      	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                               	|  1.8361e-06     	|  1              	|  1.8361e-06     	|  8.8329e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end  	|  1.7621e-06     	|  1              	|  1.7621e-06     	|  8.4767e-06     	|
# |  [LightningModule]FlowModel.on_before_batch_transfer                                                                                                              	|  1.7574e-06     	|  1              	|  1.7574e-06     	|  8.4543e-06     	|
# |  [Callback]SaveInjectionParameters.on_load_checkpoint                                                                                                             	|  1.6671e-06     	|  1              	|  1.6671e-06     	|  8.0197e-06     	|
# |  [Callback]SaveConfigCallback.on_test_end                                                                                                                         	|  1.6429e-06     	|  1              	|  1.6429e-06     	|  7.9033e-06     	|
# |  [Callback]SaveWandbUrl.on_test_start                                                                                                                             	|  1.5972e-06     	|  1              	|  1.5972e-06     	|  7.6837e-06     	|
# |  [Callback]PlotMollview.on_test_epoch_start                                                                                                                       	|  1.5791e-06     	|  1              	|  1.5791e-06     	|  7.5964e-06     	|
# |  [Callback]SaveConfigCallback.teardown                                                                                                                            	|  1.532e-06      	|  1              	|  1.532e-06      	|  7.3701e-06     	|
# |  [Callback]ProbProbPlot.on_test_start                                                                                                                             	|  1.5111e-06     	|  1              	|  1.5111e-06     	|  7.2693e-06     	|
# |  [Callback]PlotCorner.on_test_epoch_start                                                                                                                         	|  1.5059e-06     	|  1              	|  1.5059e-06     	|  7.2447e-06     	|
# |  [LightningModule]FlowModel.on_test_batch_start                                                                                                                   	|  1.4449e-06     	|  1              	|  1.4449e-06     	|  6.9512e-06     	|
# |  [Callback]SaveWandbUrl.on_test_batch_end                                                                                                                         	|  1.424e-06      	|  1              	|  1.424e-06      	|  6.8504e-06     	|
# |  [Callback]SaveFITS.setup                                                                                                                                         	|  1.4203e-06     	|  1              	|  1.4203e-06     	|  6.8325e-06     	|
# |  [Callback]PlotMollview.on_test_start                                                                                                                             	|  1.417e-06      	|  1              	|  1.417e-06      	|  6.8168e-06     	|
# |  [Callback]SaveFITS.teardown                                                                                                                                      	|  1.4063e-06     	|  1              	|  1.4063e-06     	|  6.7653e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start      	|  1.3872e-06     	|  1              	|  1.3872e-06     	|  6.6734e-06     	|
# |  [Callback]SaveInjectionParameters.on_test_start                                                                                                                  	|  1.3858e-06     	|  1              	|  1.3858e-06     	|  6.6667e-06     	|
# |  [Callback]SaveConfigCallback.on_test_start                                                                                                                       	|  1.363e-06      	|  1              	|  1.363e-06      	|  6.5569e-06     	|
# |  [Callback]PlotCorner.on_test_epoch_end                                                                                                                           	|  1.3621e-06     	|  1              	|  1.3621e-06     	|  6.5524e-06     	|
# |  [LightningModule]FlowModel.on_test_end                                                                                                                           	|  1.356e-06      	|  1              	|  1.356e-06      	|  6.5233e-06     	|
# |  [Callback]CrossMatchStatistics.on_test_epoch_start                                                                                                               	|  1.342e-06      	|  1              	|  1.342e-06      	|  6.4561e-06     	|
# |  [LightningModule]FlowModel.on_test_start                                                                                                                         	|  1.3388e-06     	|  1              	|  1.3388e-06     	|  6.4404e-06     	|
# |  [Callback]PlotMollview.on_test_end                                                                                                                               	|  1.3262e-06     	|  1              	|  1.3262e-06     	|  6.38e-06       	|
# |  [Callback]PlotCorner.on_test_start                                                                                                                               	|  1.2438e-06     	|  1              	|  1.2438e-06     	|  5.9834e-06     	|
# |  [Callback]SaveWandbUrl.on_test_batch_start                                                                                                                       	|  1.2433e-06     	|  1              	|  1.2433e-06     	|  5.9812e-06     	|
# |  [Callback]PlotMollview.on_test_batch_start                                                                                                                       	|  1.2433e-06     	|  1              	|  1.2433e-06     	|  5.9812e-06     	|
# |  [Callback]PlotMollview.setup                                                                                                                                     	|  1.2182e-06     	|  1              	|  1.2182e-06     	|  5.8602e-06     	|
# |  [Callback]SaveWandbUrl.on_test_end                                                                                                                               	|  1.2158e-06     	|  1              	|  1.2158e-06     	|  5.849e-06      	|
# |  [LightningModule]FlowModel.teardown                                                                                                                              	|  1.1818e-06     	|  1              	|  1.1818e-06     	|  5.6855e-06     	|
# |  [Callback]PlotCorner.setup                                                                                                                                       	|  1.1669e-06     	|  1              	|  1.1669e-06     	|  5.6138e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown           	|  1.1581e-06     	|  1              	|  1.1581e-06     	|  5.5713e-06     	|
# |  [Callback]SaveConfigCallback.on_test_batch_end                                                                                                                   	|  1.1437e-06     	|  1              	|  1.1437e-06     	|  5.5018e-06     	|
# |  [Callback]SaveConfigCallback.on_test_batch_start                                                                                                                 	|  1.1399e-06     	|  1              	|  1.1399e-06     	|  5.4839e-06     	|
# |  [Callback]SaveConfigCallback.on_test_epoch_end                                                                                                                   	|  1.1306e-06     	|  1              	|  1.1306e-06     	|  5.4391e-06     	|
# |  [Callback]CrossMatchStatistics.on_test_start                                                                                                                     	|  1.1208e-06     	|  1              	|  1.1208e-06     	|  5.392e-06      	|
# |  [Callback]SaveConfigCallback.on_test_epoch_start                                                                                                                 	|  1.1111e-06     	|  1              	|  1.1111e-06     	|  5.345e-06      	|
# |  [Callback]SaveFITS.on_test_start                                                                                                                                 	|  1.1101e-06     	|  1              	|  1.1101e-06     	|  5.3405e-06     	|
# |  [Callback]SaveFITS.on_test_end                                                                                                                                   	|  1.1059e-06     	|  1              	|  1.1059e-06     	|  5.3204e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start	|  1.1022e-06     	|  1              	|  1.1022e-06     	|  5.3024e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                                      	|  1.1008e-06     	|  1              	|  1.1008e-06     	|  5.2957e-06     	|
# |  [Callback]PlotCorner.teardown                                                                                                                                    	|  1.1008e-06     	|  1              	|  1.1008e-06     	|  5.2957e-06     	|
# |  [Callback]ProbProbPlot.on_test_batch_start                                                                                                                       	|  1.0999e-06     	|  1              	|  1.0999e-06     	|  5.2912e-06     	|
# |  [Callback]PlotMollview.on_test_epoch_end                                                                                                                         	|  1.0841e-06     	|  1              	|  1.0841e-06     	|  5.2151e-06     	|
# |  [Callback]SaveInjectionParameters.setup                                                                                                                          	|  1.078e-06      	|  1              	|  1.078e-06      	|  5.186e-06      	|
# |  [Callback]ProbProbPlot.on_test_epoch_start                                                                                                                       	|  1.065e-06      	|  1              	|  1.065e-06      	|  5.1232e-06     	|
# |  [Callback]SaveInjectionParameters.on_test_batch_start                                                                                                            	|  1.044e-06      	|  1              	|  1.044e-06      	|  5.0224e-06     	|
# |  [Callback]PlotCorner.on_test_end                                                                                                                                 	|  1.0221e-06     	|  1              	|  1.0221e-06     	|  4.9171e-06     	|
# |  [Callback]ProbProbPlot.on_test_batch_end                                                                                                                         	|  1.0179e-06     	|  1              	|  1.0179e-06     	|  4.897e-06      	|
# |  [Callback]ProbProbPlot.teardown                                                                                                                                  	|  1.003e-06      	|  1              	|  1.003e-06      	|  4.8253e-06     	|
# |  [Callback]PlotMollview.teardown                                                                                                                                  	|  1.0012e-06     	|  1              	|  1.0012e-06     	|  4.8163e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                       	|  9.8487e-07     	|  1              	|  9.8487e-07     	|  4.7379e-06     	|
# |  [Callback]CrossMatchStatistics.setup                                                                                                                             	|  9.7835e-07     	|  1              	|  9.7835e-07     	|  4.7066e-06     	|
# |  [Callback]CrossMatchStatistics.teardown                                                                                                                          	|  9.7463e-07     	|  1              	|  9.7463e-07     	|  4.6886e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end        	|  9.7277e-07     	|  1              	|  9.7277e-07     	|  4.6797e-06     	|
# |  [Callback]ProbProbPlot.on_test_end                                                                                                                               	|  9.723e-07      	|  1              	|  9.723e-07      	|  4.6774e-06     	|
# |  [Callback]SaveWandbUrl.teardown                                                                                                                                  	|  9.7184e-07     	|  1              	|  9.7184e-07     	|  4.6752e-06     	|
# |  [Callback]SaveWandbUrl.on_test_epoch_end                                                                                                                         	|  9.6485e-07     	|  1              	|  9.6485e-07     	|  4.6416e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                    	|  9.5833e-07     	|  1              	|  9.5833e-07     	|  4.6102e-06     	|
# |  [Callback]SaveInjectionParameters.on_test_end                                                                                                                    	|  9.5507e-07     	|  1              	|  9.5507e-07     	|  4.5946e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                  	|  9.5228e-07     	|  1              	|  9.5228e-07     	|  4.5811e-06     	|
# |  [Callback]SaveInjectionParameters.teardown                                                                                                                       	|  9.4995e-07     	|  1              	|  9.4995e-07     	|  4.5699e-06     	|
# |  [Callback]PlotCorner.on_test_batch_start                                                                                                                         	|  9.1782e-07     	|  1              	|  9.1782e-07     	|  4.4153e-06     	|
# |  [Callback]CrossMatchStatistics.on_test_batch_start                                                                                                               	|  9.0618e-07     	|  1              	|  9.0618e-07     	|  4.3593e-06     	|
# |  [Callback]CrossMatchStatistics.on_test_end                                                                                                                       	|  8.9733e-07     	|  1              	|  8.9733e-07     	|  4.3168e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': 'valid_loss', 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start	|  8.7172e-07     	|  1              	|  8.7172e-07     	|  4.1936e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                         	|  8.6986e-07     	|  1              	|  8.6986e-07     	|  4.1846e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Set parameters to prepare for generating sine Gaussian waveforms

# %%
# Desired duration of time-domain waveform
waveform_duration = 7
# Sample rate of all the data we'll be using today
sample_rate = 2048

nyquist = sample_rate / 2
num_samples = int(waveform_duration * sample_rate)
num_freqs = num_samples // 2 + 1

# %% [markdown]
# ### Define priors for waveform

# %%
from ml4gw.distributions import LogUniform
from torch.distributions import Uniform
from ml4gw.waveforms import SineGaussian
import numpy as np

# On CPU, keep the number of waveforms around 100. On GPU, you can go higher
num_waveforms = 5
num_packet = 1

param_dict = {
    "frequency": Uniform(32, 1024, False),
    "quality": Uniform(25, 75, False),
    "hrss": Uniform(1e-21, 2e-21, False),
    "phase": Uniform(0, 2 * np.pi, False),
    "eccentricity": Uniform(0, 0.01),
}
# param_dict = {
#    "frequency": Constant(512.0),
#    "quality": Uniform(25, 75, False),
#    "hrss": LogUniform(1e-21, 2e-21, False),
#    "phase": Uniform(0, 2 * np.pi, False),
#    "eccentricity": Uniform(0, 0.01),
# }
# And then sample from each of those distributions
params = {
    k: v.sample((num_waveforms,)).cpu() for k, v in param_dict.items()
}

# %%
approximant = SineGaussian(sample_rate, waveform_duration)

cross, plus = approximant(**params)
cross = cross.mean(0).unsqueeze(0)
plus = plus.mean(0).unsqueeze(0)

params_packet = {
    k: torch.mean(v) for k, v in params.items()
}
times = torch.arange(0, waveform_duration, 1 / sample_rate)
# Calling the approximant with the frequency array, reference frequency, and waveform parameters
# returns the cross and plus polarizations
print(cross.shape, plus.shape)
# Out:
# torch.Size([1, 14336]) torch.Size([1, 14336])

# %%
# Set up data coming from both detectors
from ml4gw.gw import get_ifo_geometry, compute_observed_strain

# The interferometer geometry for V1 and K1 are also in ml4gw
ifos = ["H1", "L1"]
tensors, vertices = get_ifo_geometry(*ifos)

# %%
datamodule = cli.datamodule
model = cli.model
model.eval();

# %% [markdown]
# ### Load in background data

# %%
waveforms_dataloader, background_dataloader = datamodule.test_dataloader().datasets
background_data = next(iter(background_dataloader))
background_data = background_data[0][0].repeat(num_packet, 1, 1)
print(background_data.shape)
# Out:
# torch.Size([1, 2, 38912])

# %% [markdown]
# ### Inject sg waveforms into the background data and use amplfi to predict waveform parameters

# %%
# keep sky location and ecc const
strain, asds, parameters, snrs = datamodule.inject(background_data, cross, plus, params_packet)
batch = strain, asds, parameters
print(strain.shape)
print(asds.shape)
print(parameters.shape)
print(snrs.shape)
result = model.predict_step(batch, _)
# Out:
# torch.Size([1, 2, 10240])
# torch.Size([1, 2, 4995])
# torch.Size([1, 4])
# torch.Size([1])
# 2025-08-07 10:56:35,689 - FlowModel - INFO - Removed 77/10000 total samples outside of prior range

# %% [markdown]
# ### Corner Plot

# %%
import corner
param_vals = np.array([v.item() for k, v in params_packet.items()
                       if k == 'phase' or k == 'dec' or k == 'psi' or k == 'phi'])
fig = result.plot_corner(save=False, levels=(0.5, 0.9));
corner.overplot_lines(fig, param_vals, color='r')

# %% [markdown]
# ### Take the average of the 10000 samples generated from amplfi to generate a single waveform and see how this compares to waveform generated using actual values

# %%
posterior = result.posterior
post = {key: torch.tensor([posterior[key].mean()]) for key in posterior.keys()
        if key in param_dict.keys()}

# Phase of the two waveforms do not match up unless I set the phase for the posterior to be the
# same as the prior
# post['phase'] = params['phase']

# %%
from scipy.stats import probplot
num_params = len(posterior.keys()[:-2])
fig, axes = plt.subplots(2, 2, sharex=True, figsize = (10, 10))
post_plot = posterior.to_numpy().T
key = posterior.keys()
probplot(post_plot[0], plot=axes[0, 0])
probplot(post_plot[1], plot=axes[0, 1])
probplot(post_plot[2], plot=axes[1, 0])
probplot(post_plot[3], plot=axes[1, 1])
axes[0, 0].set_title(key[0])
axes[0, 1].set_title(key[1])
axes[1, 0].set_title(key[2])
axes[1, 1].set_title(key[3])
plt.tight_layout()

# %% [markdown]
# ### Generate waveforms from prior values

# %%
waveforms = compute_observed_strain(
    dec=torch.tensor([params_packet['dec']]),
    psi=torch.tensor([params_packet['psi']]),
    phi=torch.tensor([params_packet['phi']]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross,
    plus=plus,
)

# %% [markdown]
# ### Generate waveforms from average of posterior values

# %%
cross_pred, plus_pred = approximant(**post)

waveforms_pred = compute_observed_strain(
    dec=torch.tensor([posterior['dec'].mean()]),
    psi=torch.tensor([posterior['psi'].mean()]),
    phi=torch.tensor([posterior['phi'].mean()]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross_pred,
    plus=plus_pred,
)
print(waveforms_pred.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 cross_pred, plus_pred = approximant(**post)
#       3 waveforms_pred = compute_observed_strain(
#       4     dec=torch.tensor([posterior['dec'].mean()]),
#       5     psi=torch.tensor([posterior['psi'].mean()]),
#    (...)
#      11     plus=plus_pred,
#      12 )
#      13 print(waveforms_pred.shape)
#
# File ~/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/amplfi_dir/amplfi/.venv/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# TypeError: SineGaussian.forward() missing 4 required positional arguments: 'quality', 'frequency', 'hrss', and 'eccentricity'

# %%
mean_waveform_pred = waveforms_pred.mean(0)
print(mean_waveform_pred.shape)
print(waveforms.shape)
# Out:
# torch.Size([2, 14336])
# torch.Size([1, 2, 14336])

# %% [markdown]
# ### Plot waveforms together

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=True, figsize=(15, 7))
ax[0].plot(times, waveforms[0, 0].cpu(), color='k', label="original", alpha=0.5)
ax[0].plot(times, mean_waveform_pred[0].cpu (), color='r', label="predicted", alpha=0.5)
ax[1].plot(times, waveforms[0, 1].cpu(), color='k', alpha=0.5)
ax[1].plot(times, mean_waveform_pred[1].cpu(), color='r', alpha=0.5)
ax[1].set_xlabel("Time (s)")
ax[0].set_ylabel("Strain H1")
ax[1].set_ylabel("Strain L1")
ax[0].legend()
ax[1].set_xlim(3.4, 3.6)
plt.show()

# %% [markdown]
# ### Try generating all 10000 waveforms first, then taking the average of all of the waveforms

# %%
posterior = result.posterior
post = {key: torch.tensor([posterior[key]]) for key in posterior.keys()
        if key in param_dict.keys()}

# %%
cross_pred, plus_pred = approximant(**post)

waveforms_pred = compute_observed_strain(
    dec=torch.tensor([posterior['dec']]),
    psi=torch.tensor([posterior['psi']]),
    phi=torch.tensor([posterior['phi']]),
    detector_tensors=tensors,
    detector_vertices=vertices,
    sample_rate=sample_rate,
    cross=cross_pred,
    plus=plus_pred,
)
print(waveforms_pred.shape)
# Out:
# torch.Size([8529, 2, 14336])

# %%
percentile_waveform_pred = np.percentile(waveforms_pred.cpu(), [5, 95], axis=0)
print(percentile_waveform_pred.shape)
print(mean_waveform_pred.shape)
print(waveforms.shape)
# Out:
# (2, 2, 14336)
# torch.Size([2, 14336])
# torch.Size([1, 2, 14336])

# %%
fig, ax = plt.subplots(2, sharex=True, sharey=True, figsize=(10, 5))
ax[0].plot(times, waveforms[0, 0].cpu(), color='k', alpha=0.5)
ax[0].fill_between(times, percentile_waveform_pred[0, 0], percentile_waveform_pred[1, 0], alpha=0.5)
ax[1].plot(times, waveforms[0, 1].cpu(), color='k', alpha=0.5)
ax[1].fill_between(times, percentile_waveform_pred[0, 1], percentile_waveform_pred[1, 1], alpha=0.5)
ax[1].set_xlabel("Time (s)")
ax[0].set_ylabel("Strain H1")
ax[1].set_ylabel("Strain L1")
ax[1].set_xlim(3.4, 3.6)
plt.tight_layout()
# plt.savefig("./images/sg_packet.png")
plt.show()

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=(15, 7))
wave_ave = 0
num_waves = 1000
ip = len(waveforms_pred) // num_waves + 1
for wave in waveforms_pred[::ip, 0, :]:
    ax[0].plot(times, wave)
    wave_ave += wave
wave_ave /= num_waves
ax[1].plot(times, wave_ave)
ax[2].plot(times, waveforms[0, 0])
ax[0].set_xlim(3.4, 3.6)
plt.show()

# %%
fig, ax = plt.subplots(3, sharex=True, figsize=(15, 7))
wave_ave = 0
ip = len(waveforms_pred) // num_waves + 1
for wave in waveforms_pred[::ip, 1, :]:
    ax[0].plot(times, wave)
    wave_ave += wave
wave_ave /= num_waves
ax[1].plot(times, wave_ave)
ax[2].plot(times, waveforms[0, 1])
# ax[0].set_xlim(3.4, 3.6)
plt.show()
